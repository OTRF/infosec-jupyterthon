# %% [markdown]
# ## InfoSec Jupyterthon Day 1
#
# ---
#
# # 3. Basics of Data Analysis with Pandas
#
# Contents
# - DataFrame, an organized way to represent data.
# - Importing data into a data frame
# - Selection - rows and columns
# - Filtering
# - Grouping
# - Adding and removing columns
# - Simple joining of multiple dataframes
# - Statistics 101

# %% [markdown]
# ---
#
# # Representing data in an Organized way: Dataframe
#
# ## Storing data in Python objects
#
# - Importing libraries:

# %% [markdown]
# ## Pandas Structures
# ### Series
# A Pandas Series is a one-dimensional array-like object that can hold any data type, with a single Series holding multiple data types if needed. The axis labels area refered to as index.
#
# They can be created from a range of different data structures, including a list, ndarry, dictionary or scalar value.
#
# If creating from an list like below we can either specify the index or one can be automatically created.

# %%
import pandas as pd
data = ["Item 1", "Item 2", "Item 3"]
pd.Series(data, index=[1,2,3])
#pd.Series(data, index=["A","B","C"])
# Out:
# 1    Item 1
# 2    Item 2
# 3    Item 3
# dtype: object

# %% [markdown]
# When creating from a dictionary an index does not need to be supplied and will be infered from the Dictionary keys:

# %%
data = {"A": "Item 1", "B": "Item 2", "C": "Item 3"}
pd.Series(data)
# Out:
# A    Item 1
# B    Item 2
# C    Item 3
# dtype: object

# %% [markdown]
# You can also attach names to a Series, this can help with later understanding.

# %%
data = {"A": "Item 1", "B": "Item 2", "C": "Item 3"}
examples_series = pd.Series(data, name="Dictionary Series")
examples_series.name
# Out:
# 'Dictionary Series'

# %% [markdown]
# More on Series: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html

# %% [markdown]
# ### DataFrame
# A Pandas DataFrame is a two-dimensional tabular data structure with labeled axes (rows and columns). Similar to a table.
#
# A DataFrame can be considered to be make up for multiple Series, with each row being its own Series, and as with Series not each column in an DataFrame is necessarily the same type of data.
#
# DataFrames can be created from a range of input types includesing, lists, tuples, dictionaries, Series, ndarrays, or other DataFrames.
#
# As well as the index that a Series has, DataFrames have a second index called 'columns', which contains the names assigned to each column in the DataFrame.

# %%
import pandas as pd
data = {"Name": ["Item 1", "Item 2", "Item 3"], "Value": ["6.0", "3.2", "11.9"], "Count": [111, 720, 82]}
pd.DataFrame(data)
# Out:
#      Name Value  Count
# 0  Item 1   6.0    111
# 1  Item 2   3.2    720
# 2  Item 3  11.9     82

# %% [markdown]
# In the example above the columns are infered from the keys of the dictionary and the index is autogenearted. We can also specify the index if we need:

# %%
import pandas as pd
data = {"Name": ["Item 1", "Item 2", "Item 3"], "Value": ["6.0", "3.2", "11.9"], "Count": [111, 720, 82]}
pd.DataFrame(data, index=["Item 1", "Item 2", "Item 3"])
# Out:
#           Name Value  Count
# Item 1  Item 1   6.0    111
# Item 2  Item 2   3.2    720
# Item 3  Item 3  11.9     82

# %% [markdown]
# You can also create a DataFrame from a group of Series:

# %%
data = {"A": "Item 1", "B": "1", "C": "12.3"}
data2 = {"A": "Item 4", "B": "6", "C": "17.1"}
pd.DataFrame([data, data2])
# Out:
#         A  B     C
# 0  Item 1  1  12.3
# 1  Item 4  6  17.1

# %% [markdown]
# You can also choose to use a column as the index if you wish:

# %%
data = {"A": "Item 1", "B": "1", "C": "12.3"}
data2 = {"A": "Item 4", "B": "6", "C": "17.1"}
df = pd.DataFrame([data, data2])
df.set_index("A")
# Out:
#         B     C
# A
# Item 1  1  12.3
# Item 4  6  17.1

# %% [markdown]
# More on DataFrames can be found here:
#
# [https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)

# %% [markdown]
# Pandas also supports the creation of a DataFrame from a wide array of structured datasets including:
#  - JSON
#  - CSV
#  - Excel
#  - SQL
#  - HTML
#  - XML
#  - Pickles
#
# These are all accessible by using Panda's read_* methods:

# %%
import pandas as pd
csv_df = pd.read_csv("../data/process_tree.csv")
csv_df.head()
# Out:
#    Unnamed: 0                              TenantId  \
# 0           0  802d39e1-9d70-404d-832c-2de5e2478eda
# 1           1  802d39e1-9d70-404d-832c-2de5e2478eda
# 2           2  802d39e1-9d70-404d-832c-2de5e2478eda
# 3           3  802d39e1-9d70-404d-832c-2de5e2478eda
# 4           4  802d39e1-9d70-404d-832c-2de5e2478eda
#
#                       Account  EventID            TimeGenerated  \
# 0  MSTICAlertsWin1\MSTICAdmin     4688  2019-01-15 05:15:15.677
# 1  MSTICAlertsWin1\MSTICAdmin     4688  2019-01-15 05:15:16.167
# 2  MSTICAlertsWin1\MSTICAdmin     4688  2019-01-15 05:15:16.277
# 3  MSTICAlertsWin1\MSTICAdmin     4688  2019-01-15 05:15:16.340
# 4  MSTICAlertsWin1\MSTICAdmin     4688  2019-01-15 05:15:16.400
#
#           Computer                                SubjectUserSid  \
# 0  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 1  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 2  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 3  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 4  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
#
#   SubjectUserName SubjectDomainName SubjectLogonId  ...  \
# 0      MSTICAdmin   MSTICAlertsWin1       0xfaac27  ...
# 1      MSTICAdmin   MSTICAlertsWin1       0xfaac27  ...
# 2      MSTICAdmin   MSTICAlertsWin1       0xfaac27  ...
# 3      MSTICAdmin   MSTICAlertsWin1       0xfaac27  ...
# 4      MSTICAdmin   MSTICAlertsWin1       0xfaac27  ...
#
#                         NewProcessName TokenElevationType ProcessId  \
# 0       C:\Diagnostics\UserTmp\ftp.exe             %%1936     0xbc8
# 1       C:\Diagnostics\UserTmp\reg.exe             %%1936     0xbc8
# 2       C:\Diagnostics\UserTmp\cmd.exe             %%1936     0xbc8
# 3  C:\Diagnostics\UserTmp\rundll32.exe             %%1936     0xbc8
# 4  C:\Diagnostics\UserTmp\rundll32.exe             %%1936     0xbc8
#
#                                          CommandLine  \
# 0                   .\ftp  -s:C:\RECYCLER\xxppyy.exe
# 1  .\reg  not /domain:everything that /sid:shines...
# 2                 cmd  /c "systeminfo && systeminfo"
# 3                           .\rundll32  /C 12345.exe
# 4       .\rundll32  /C c:\users\MSTICAdmin\12345.exe
#
#              ParentProcessName TargetLogonId  \
# 0  C:\Windows\System32\cmd.exe           0x0
# 1  C:\Windows\System32\cmd.exe           0x0
# 2  C:\Windows\System32\cmd.exe           0x0
# 3  C:\Windows\System32\cmd.exe           0x0
# 4  C:\Windows\System32\cmd.exe           0x0
#
#                        SourceComputerId           TimeCreatedUtc NodeRole  \
# 0  46fe7078-61bb-4bed-9430-7ac01d91c273  2019-01-15 05:15:15.677   source
# 1  46fe7078-61bb-4bed-9430-7ac01d91c273  2019-01-15 05:15:16.167  sibling
# 2  46fe7078-61bb-4bed-9430-7ac01d91c273  2019-01-15 05:15:16.277  sibling
# 3  46fe7078-61bb-4bed-9430-7ac01d91c273  2019-01-15 05:15:16.340  sibling
# 4  46fe7078-61bb-4bed-9430-7ac01d91c273  2019-01-15 05:15:16.400  sibling
#
#   Level
# 0     0
# 1     1
# 2     1
# 3     1
# 4     1
#
# [5 rows x 21 columns]

# %%
pkl_df = pd.read_pickle("../data/host_logons.pkl")
pkl_df.head()
# Out:
#                                TenantId                     Account  EventID  \
# 0  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM     4624
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 3  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 4  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 0 2019-02-12 04:56:34.307  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 3 2019-02-12 04:38:16.550  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 4 2019-02-12 04:38:21.370  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 0  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 1  MSTICAlertsWin1                 -                 -        S-1-0-0
# 2  MSTICAlertsWin1                 -                 -        S-1-0-0
# 3  MSTICAlertsWin1                 -                 -        S-1-0-0
# 4  MSTICAlertsWin1                 -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 0         SYSTEM     NT AUTHORITY
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
# 3     MSTICAdmin  MSTICAlertsWin1
# 4     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 0                                      S-1-5-18         0x3e7
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
# 3  S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 4  S-1-5-21-996632719-2361334927-4038480536-500     0xc913737
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 0         Advapi            5                 Negotiate
# 1         NtLmSsp           3                      NTLM
# 2         NtLmSsp           3                      NTLM
# 3         NtLmSsp           3                      NTLM
# 4         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 0                -               - 2019-02-12 04:56:34.307
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997
# 3  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:38:16.550
# 4  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:38:21.370

# %% [markdown]
# There are also a wide range of parameters you can set when calling the read_* function. One of the most user is the `parse_dates` parameter, which allows you to specify columns which contain timestamps that you want to parse into datetime objects.<br>
# You can also user `date_parser` to specify what format the timestamp strings are in and how they should be interpreted.

# %%
import pandas as pd
df = pd.read_csv("../data/process_tree.csv")
print(type(df.iloc[0]["TimeGenerated"]))
df = pd.read_csv("../data/process_tree.csv", parse_dates=["TimeGenerated"])
print(type(df.iloc[0]["TimeGenerated"]))
# Out:
# <class 'str'>
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %% [markdown]
# The paths supplied to files vary depending on the type of read_* method used but most accept a path to a file in the local file system or paths to remote files e.g. `pd.read_csv('https://s3.amazonaws.com/mybucket/mydata.csv')`
#
# More details on Panda's read_* functions can be found here: https://pandas.pydata.org/docs/user_guide/io.html

# %%
import pandas as pd

# We're going to read another data set in with more variety
logons_full_df = pd.read_pickle("../data/host_logons.pkl")
net_full_df = pd.read_pickle("../data/az_net_comms_df.pkl")

# also create a demo version with just 20 rows
logons_df = logons_full_df.sample(20)
logons_df.head(5)
# Out:
#                  Account  EventID           TimeGenerated         Computer  \
# 55   NT AUTHORITY\SYSTEM     4624 2019-02-14 04:12:44.970  MSTICAlertsWin1
# 69   NT AUTHORITY\SYSTEM     4624 2019-02-13 22:08:46.537  MSTICAlertsWin1
# 43   NT AUTHORITY\SYSTEM     4624 2019-02-10 20:03:29.680  MSTICAlertsWin1
# 107  NT AUTHORITY\SYSTEM     4624 2019-02-13 20:08:47.880  MSTICAlertsWin1
# 94   NT AUTHORITY\SYSTEM     4624 2019-02-13 20:09:41.273  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 55   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 69   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 43   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 107  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 94   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 55      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 69      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 43      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 107     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 94      NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 55                - 2019-02-14 04:12:44.970
# 69                - 2019-02-13 22:08:46.537
# 43                - 2019-02-10 20:03:29.680
# 107               - 2019-02-13 20:08:47.880
# 94                - 2019-02-13 20:09:41.273

# %%
print("Single row of DataFrame")
display(logons_df.iloc[0].head())
print("Type of single row - logons_df.iloc[0])", type(logons_df.iloc[0])) # First row
# Out:
# Single row of DataFrame
# TenantId            52b1ab41-869e-4138-9e40-2a4457f09bf0
# Account                              NT AUTHORITY\SYSTEM
# EventID                                             4624
# TimeGenerated                 2019-02-14 04:51:37.183000
# SourceComputerId    263a788b-6526-4cdc-8ed9-d79402fe4aa0
# Name: 67, dtype: object
# Type of single row - logons_df.iloc[0]) <class 'pandas.core.series.Series'>

# %%
# At the intersection of a row and column we get a simple type - the cell content
print("\nIntersection - logons_df.iloc[0].Account", type(logons_df.iloc[0].Account), logons_df.iloc[0].Account)
# Out:
# Intersection - logons_df.iloc[0].Account <class 'str'> NT AUTHORITY\SYSTEM

# %% [markdown]
# ## Selecting Columns
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.<i>column_name</i><br>
# df[<i>column_name</i>]
# </p>

# %% [markdown]
# Selecting a single column

# %%
logons_df.Account.head()
# Out:
# 67     NT AUTHORITY\SYSTEM
# 118    NT AUTHORITY\SYSTEM
# 149    NT AUTHORITY\SYSTEM
# 76     NT AUTHORITY\SYSTEM
# 51     NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %% [markdown]
# More general syntax and mandatory if column name has spaces or other illegal chars (like ".")

# %%
logons_df["Account"].head()
# Out:
# 67     NT AUTHORITY\SYSTEM
# 118    NT AUTHORITY\SYSTEM
# 149    NT AUTHORITY\SYSTEM
# 76     NT AUTHORITY\SYSTEM
# 51     NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %% [markdown]
# To select multiple columns you use a Python list

# %%
my_cols = ["Account", "TimeGenerated"]
logons_df[my_cols].head()
# Out:
#                  Account           TimeGenerated
# 67   NT AUTHORITY\SYSTEM 2019-02-14 04:51:37.183
# 118  NT AUTHORITY\SYSTEM 2019-02-12 21:39:15.897
# 149  NT AUTHORITY\SYSTEM 2019-02-15 08:51:51.763
# 76   NT AUTHORITY\SYSTEM 2019-02-14 04:20:54.987
# 51   NT AUTHORITY\SYSTEM 2019-02-09 12:32:50.220

# %%
# Or just (note the [list], within the [] indexer syntax)
logons_df[["Account", "TimeGenerated"]].head()
# Out:
#                  Account           TimeGenerated
# 67   NT AUTHORITY\SYSTEM 2019-02-14 04:51:37.183
# 118  NT AUTHORITY\SYSTEM 2019-02-12 21:39:15.897
# 149  NT AUTHORITY\SYSTEM 2019-02-15 08:51:51.763
# 76   NT AUTHORITY\SYSTEM 2019-02-14 04:20:54.987
# 51   NT AUTHORITY\SYSTEM 2019-02-09 12:32:50.220

# %% [markdown]
# ### Use the columns property to get the column names

# %%
logons_df.columns
# Out:
# Index(['TenantId', 'Account', 'EventID', 'TimeGenerated', 'SourceComputerId',
#        'Computer', 'SubjectUserName', 'SubjectDomainName', 'SubjectUserSid',
#        'TargetUserName', 'TargetDomainName', 'TargetUserSid', 'TargetLogonId',
#        'LogonProcessName', 'LogonType', 'AuthenticationPackageName', 'Status',
#        'IpAddress', 'WorkstationName', 'TimeCreatedUtc'],
#       dtype='object')

# %% [markdown]
# ## Indexes - brief introduction
#
# Pandas default index is a monotonically-increasing integer (a Python range)

# %%
logons_df.index
# Out:
# Int64Index([ 67, 118, 149,  76,  51,  73,  15, 132,   4, 147, 131,  75,  79,
#              60, 163,  43,  69,  26, 121, 108],
#            dtype='int64')

# %% [markdown]
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.loc[<i>index_value</i>]<br>vs.<br>
# df.iloc[<i>row#</i>]
# </p>

# %%
# Access a row at an index location
logons_df.loc[118]
# Out:
# TenantId                     52b1ab41-869e-4138-9e40-2a4457f09bf0
# Account                                       NT AUTHORITY\SYSTEM
# EventID                                                      4624
# TimeGenerated                          2019-02-12 21:39:15.897000
# SourceComputerId             263a788b-6526-4cdc-8ed9-d79402fe4aa0
# Computer                                          MSTICAlertsWin1
# SubjectUserName                                  MSTICAlertsWin1$
# SubjectDomainName                                       WORKGROUP
# SubjectUserSid                                           S-1-5-18
# TargetUserName                                             SYSTEM
# TargetDomainName                                     NT AUTHORITY
# TargetUserSid                                            S-1-5-18
# TargetLogonId                                               0x3e7
# LogonProcessName                                         Advapi
# LogonType                                                       5
# AuthenticationPackageName                               Negotiate
# Status
# IpAddress                                                       -
# WorkstationName                                                 -
# TimeCreatedUtc                         2019-02-12 21:39:15.897000
# Name: 118, dtype: object

# %%
# Access a row at a physical row location
logons_df.iloc[1]
# Out:
# TenantId                     52b1ab41-869e-4138-9e40-2a4457f09bf0
# Account                                       NT AUTHORITY\SYSTEM
# EventID                                                      4624
# TimeGenerated                          2019-02-12 21:39:15.897000
# SourceComputerId             263a788b-6526-4cdc-8ed9-d79402fe4aa0
# Computer                                          MSTICAlertsWin1
# SubjectUserName                                  MSTICAlertsWin1$
# SubjectDomainName                                       WORKGROUP
# SubjectUserSid                                           S-1-5-18
# TargetUserName                                             SYSTEM
# TargetDomainName                                     NT AUTHORITY
# TargetUserSid                                            S-1-5-18
# TargetLogonId                                               0x3e7
# LogonProcessName                                         Advapi
# LogonType                                                       5
# AuthenticationPackageName                               Negotiate
# Status
# IpAddress                                                       -
# WorkstationName                                                 -
# TimeCreatedUtc                         2019-02-12 21:39:15.897000
# Name: 118, dtype: object

# %% [markdown]
# ### Setting another column as index
#
# <p style="font-family:consolas; font-size:15pt; color:green; color:green">
# df.set_index(<i>column_name</i>)
# </p>

# %%
indexed_logons_df = logons_df.set_index("Account")
display(logons_df.head(3))
print("Indexed by Account column")
display(indexed_logons_df.head(3))
print("Locating rows by index value (note index is NOT unique)")
display(indexed_logons_df.loc["MSTICAlertsWin1\\MSTICAdmin"].head(3))
# Out:
#                 Account  EventID           TimeGenerated         Computer  \
# 55  NT AUTHORITY\SYSTEM     4624 2019-02-14 04:12:44.970  MSTICAlertsWin1
# 69  NT AUTHORITY\SYSTEM     4624 2019-02-13 22:08:46.537  MSTICAlertsWin1
# 43  NT AUTHORITY\SYSTEM     4624 2019-02-10 20:03:29.680  MSTICAlertsWin1
#
#      SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 55  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 69  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 43  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#    TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 55     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 69     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 43     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#    WorkstationName          TimeCreatedUtc
# 55               - 2019-02-14 04:12:44.970
# 69               - 2019-02-13 22:08:46.537
# 43               - 2019-02-10 20:03:29.680
# Indexed by Account column
#                      EventID           TimeGenerated         Computer  \
# Account
# NT AUTHORITY\SYSTEM     4624 2019-02-14 04:12:44.970  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM     4624 2019-02-13 22:08:46.537  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM     4624 2019-02-10 20:03:29.680  MSTICAlertsWin1
#
#                       SubjectUserName SubjectDomainName SubjectUserSid  \
# Account
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#                     TargetUserName TargetDomainName TargetUserSid  \
# Account
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
#
#                     TargetLogonId  LogonType IpAddress WorkstationName  \
# Account
# NT AUTHORITY\SYSTEM         0x3e7          5         -               -
# NT AUTHORITY\SYSTEM         0x3e7          5         -               -
# NT AUTHORITY\SYSTEM         0x3e7          5         -               -
#
#                              TimeCreatedUtc
# Account
# NT AUTHORITY\SYSTEM 2019-02-14 04:12:44.970
# NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537
# NT AUTHORITY\SYSTEM 2019-02-10 20:03:29.680
# Locating rows by index value (note index is NOT unique)
# EventID                                4624
# TimeGenerated    2019-02-15 03:57:02.593000
# Computer                    MSTICAlertsWin1
# Name: MSTICAlertsWin1\MSTICAdmin, dtype: object

# %%
# Physical row indexing works as before
indexed_logons_df.iloc[1]
# Out:
# EventID                                    4624
# TimeGenerated        2019-02-13 22:08:46.537000
# Computer                        MSTICAlertsWin1
# SubjectUserName                MSTICAlertsWin1$
# SubjectDomainName                     WORKGROUP
# SubjectUserSid                         S-1-5-18
# TargetUserName                           SYSTEM
# TargetDomainName                   NT AUTHORITY
# TargetUserSid                          S-1-5-18
# TargetLogonId                             0x3e7
# LogonType                                     5
# IpAddress                                     -
# WorkstationName                               -
# TimeCreatedUtc       2019-02-13 22:08:46.537000
# Name: NT AUTHORITY\SYSTEM, dtype: object

# %% [markdown]
# ## Accessing individual values
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.iloc[expr].ColumnName<br>
# df.at[index_expr, ColumnName]<br>
# df.iat[row#, col#]
# </p>

# %%
print("iloc + named column", logons_df.iloc[0].Account)
print("at - row idx + named column", logons_df.at[0, "Account"])
print("iat - row idx + column idx", logons_df.iat[0, 1])


print("\nBut if the index is not unique 'at' returns a series\n")

print(
    "at - row idx + named column",
    "Type:",
    type(indexed_logons_df.at["NT AUTHORITY\\SYSTEM", "EventID"]),
    "Result:",
    indexed_logons_df.at["NT AUTHORITY\\SYSTEM", "EventID"],
    sep="\n",
)
# Out:
# iloc + named column NT AUTHORITY\SYSTEM
# at - row idx + named column NT AUTHORITY\SYSTEM
# iat - row idx + column idx NT AUTHORITY\SYSTEM
#
# But if the index is not unique 'at' returns a series
#
# at - row idx + named column
# Type:
# <class 'pandas.core.series.Series'>
# Result:
# Account
# NT AUTHORITY\SYSTEM    4624
# NT AUTHORITY\SYSTEM    4624
# NT AUTHORITY\SYSTEM    4624
# NT AUTHORITY\SYSTEM    4624
# NT AUTHORITY\SYSTEM    4624
# NT AUTHORITY\SYSTEM    4624
# Name: EventID, dtype: int64

# %% [markdown]
# ---
#
# # Exporting/Importing data (cont.)

# %% [markdown]
# ## CSV Files
#
# We covered CSV importing and datetime parsing.
#
# Other useful options for CSV include:
# <p style="font-family:consolas; font-size:15pt; color:green">
# pd.read_csv(<br>
# &nbsp;&nbsp;file_path,<br>
# &nbsp;&nbsp;index_col=0,<br>
# &nbsp;&nbsp;header=row_num,<br>
# &nbsp;&nbsp;on_bad_lines{‘error’, ‘warn’, ‘skip’},<br>
# )
#
# <p>
#
# - CSV is universal but a bit nasty.
# - Pickle is good but has changing different format across different Python version
#
# Good options are:
# - Parquet
# - HDF
# - Feather

# %% [markdown]
# ## DataFrame output functions

# %%
df = pd.DataFrame
for func_name in dir(df):
    if func_name.startswith("to_"):
        doc = getattr(df, func_name).__doc__.split("\n")
        print(func_name, ":" + " " * (20 - len(func_name)) , doc[1].strip())
# Out:
# to_clipboard :         Copy object to the system clipboard.
# to_csv :               Write object to a comma-separated values (csv) file.
# to_dict :              Convert the DataFrame to a dictionary.
# to_excel :             Write object to an Excel sheet.
# to_feather :           Write a DataFrame to the binary Feather format.
# to_gbq :               Write a DataFrame to a Google BigQuery table.
# to_hdf :               Write the contained data to an HDF5 file using HDFStore.
# to_html :              Render a DataFrame as an HTML table.
# to_json :              Convert the object to a JSON string.
# to_latex :             Render object to a LaTeX tabular, longtable, or nested table/tabular.
# to_markdown :          Print DataFrame in Markdown-friendly format.
# to_numpy :             Convert the DataFrame to a NumPy array.
# to_parquet :           Write a DataFrame to the binary parquet format.
# to_period :            Convert DataFrame from DatetimeIndex to PeriodIndex.
# to_pickle :            Pickle (serialize) object to file.
# to_records :           Convert DataFrame to a NumPy record array.
# to_sql :               Write records stored in a DataFrame to a SQL database.
# to_stata :             Export DataFrame object to Stata dta format.
# to_string :            Render a DataFrame to a console-friendly tabular output.
# to_timestamp :         Cast to DatetimeIndex of timestamps, at *beginning* of period.
# to_xarray :            Return an xarray object from the pandas object.

# %% [markdown]
# ## DataFrame input functions

# %%
for func_name in dir(pd):
    if func_name.startswith("read_"):
        doc = getattr(pd, func_name).__doc__.split("\n")
        print(func_name, ":" + " " * (20 - len(func_name)) , doc[1].strip())
# Out:
# read_clipboard :       Read text from clipboard and pass to read_csv.
# read_csv :             Read a comma-separated values (csv) file into DataFrame.
# read_excel :           Read an Excel file into a pandas DataFrame.
# read_feather :         Load a feather-format object from the file path.
# read_fwf :             Read a table of fixed-width formatted lines into DataFrame.
# read_gbq :             Load data from Google BigQuery.
# read_hdf :             Read from the store, close it if we opened it.
# read_html :            Read HTML tables into a ``list`` of ``DataFrame`` objects.
# read_json :            Convert a JSON string to pandas object.
# read_orc :             Load an ORC object from the file path, returning a DataFrame.
# read_parquet :         Load a parquet object from the file path, returning a DataFrame.
# read_pickle :          Load pickled pandas object (or any object) from file.
# read_sas :             Read SAS files stored as either XPORT or SAS7BDAT format files.
# read_spss :            Load an SPSS file from the file path, returning a DataFrame.
# read_sql :             Read SQL query or database table into a DataFrame.
# read_sql_query :       Read SQL query into a DataFrame.
# read_sql_table :       Read SQL database table into a DataFrame.
# read_stata :           Read Stata file into DataFrame.
# read_table :           Read general delimited file into DataFrame.

# %% [markdown]
# ## Excel - typically need `openpyxl` installed

# %%
procs_df.to_excel("../data/excel_sample.xlsx")

# !start ../data/excel_sample.xlsx

# %% [markdown]
# ## JSON and json_normalize

# %%
json_text = """
[
    {"Computer":"MSTICAlertsWin1","Account":"MSTICAdmin","NewProcessName":"ftp.exe"},
    {"Computer":"MSTICAlertsWin1","Account":"MSTICAdmin","NewProcessName":"reg.exe"},
    {"Computer":"MSTICAlertsWin1","Account":"MSTICAdmin","NewProcessName":"cmd.exe"},
    {"Computer":"MSTICAlertsWin1","Account":"MSTICAdmin","NewProcessName":"rundll32.exe"},
    {"Computer":"MSTICAlertsWin1","Account":"MSTICAdmin","NewProcessName":"rundll32.exe"}
]
"""

# %%
pd.read_json(json_text)
# Out:
#           Computer     Account NewProcessName
# 0  MSTICAlertsWin1  MSTICAdmin        ftp.exe
# 1  MSTICAlertsWin1  MSTICAdmin        reg.exe
# 2  MSTICAlertsWin1  MSTICAdmin        cmd.exe
# 3  MSTICAlertsWin1  MSTICAdmin   rundll32.exe
# 4  MSTICAlertsWin1  MSTICAdmin   rundll32.exe

# %% [markdown]
# ### Note: `json_normalize` expects a Python `dict`, not JSON

# %%
json_nested_text = """
[
    {
        "Computer":"MSTICAlertsWin1",
        "SubRecord": {"NewProcessName":"ftp.exe", "pid": 1}
    },
    {
        "Computer":"MSTICAlertsWin1",
        "SubRecord": {"NewProcessName":"reg.exe", "pid": 2}
    },
    {
        "Computer":"MSTICAlertsWin1",
        "SubRecord": {"NewProcessName":"cmd.exe", "pid": 3}
    }
]
"""

try:
    pd.json_normalize(json_nested_text)
except Exception as err:
    print("oh-oh - raw JSON!:", err)

import json

pd.json_normalize(json.loads(json_nested_text))
# Out:
# oh-oh - raw JSON!: 'str' object has no attribute 'values'
#           Computer SubRecord.NewProcessName  SubRecord.pid
# 0  MSTICAlertsWin1                  ftp.exe              1
# 1  MSTICAlertsWin1                  reg.exe              2
# 2  MSTICAlertsWin1                  cmd.exe              3

# %% [markdown]
# ---
# # Selecting/Searching

# %% [markdown]
# ## Specific row (or col) by number
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.iloc[row#]/df.iloc[row-range]
# </p>

# %%
logons_df.iloc[2].Account
# Out:
# 'MSTICAlertsWin1\\MSTICAdmin'

# %%
logons_df.iloc[3:6]
# Out:
#                  Account  EventID           TimeGenerated         Computer  \
# 107  NT AUTHORITY\SYSTEM     4624 2019-02-13 20:08:47.880  MSTICAlertsWin1
# 94   NT AUTHORITY\SYSTEM     4624 2019-02-13 20:09:41.273  MSTICAlertsWin1
# 28   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:11.573  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 107  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 94   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 28   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 107     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 94      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 28      NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 107               - 2019-02-13 20:08:47.880
# 94                - 2019-02-13 20:09:41.273
# 28                - 2019-02-12 04:40:11.573

# %% [markdown]
# ### You can go full numpy and use `iloc` with int indexing

# %%
logons_df.iloc[2, 0]
# Out:
# 'NT AUTHORITY\\SYSTEM'

# %% [markdown]
# ## Select by content - "Boolean indexing"
#
# ### Basic operators
# <p style="font-family:consolas; font-size:15pt; color:green">
#  ==<br>
#  !=<br>
#  >, <, >=, <=
# </p>

# %%
logons_df["Account"] == "MSTICAlertsWin1\\MSTICAdmin"
# Out:
# 0     False
# 1      True
# 2      True
# 3      True
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# Name: Account, dtype: bool

# %% [markdown]
# ### Use boolean result of expression to filter DataFrame
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df[<i>bool_expr</i>]
# </p>
#
# ### Note
# <p style="font-family:consolas; font-size:15pt; color:green">
# df[<i>bool_expr</i>] == df.<b>loc</b>[<i>bool_expr</i>]
# </p>

# %%
logons_df.loc[logons_df["Account"] == "MSTICAlertsWin1\\MSTICAdmin"]
# Out:
#                                TenantId                     Account  EventID  \
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 3  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 4  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 3 2019-02-12 04:38:16.550  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 4 2019-02-12 04:38:21.370  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 1  MSTICAlertsWin1               -                 -        S-1-0-0
# 2  MSTICAlertsWin1               -                 -        S-1-0-0
# 3  MSTICAlertsWin1               -                 -        S-1-0-0
# 4  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
# 3     MSTICAdmin  MSTICAlertsWin1
# 4     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
# 3  S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 4  S-1-5-21-996632719-2361334927-4038480536-500     0xc913737
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 1         NtLmSsp           3                      NTLM
# 2         NtLmSsp           3                      NTLM
# 3         NtLmSsp           3                      NTLM
# 4         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997
# 3  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:38:16.550
# 4  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:38:21.370

# %% [markdown]
# ## Other operators with boolean indexing
#
# Operators vary depending on data type!!!

# %%
logons_df.dtypes
# Out:
# Account                      object
# EventID                       int64
# TimeGenerated        datetime64[ns]
# Computer                     object
# SubjectUserName              object
# SubjectDomainName            object
# SubjectUserSid               object
# TargetUserName               object
# TargetDomainName             object
# TargetUserSid                object
# TargetLogonId                object
# LogonType                     int64
# IpAddress                    object
# WorkstationName              object
# TimeCreatedUtc       datetime64[ns]
# dtype: object

# %%
logons_df[logons_df["Account"].endswith("MSTICAdmin")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8680/3533411303.py in <module>
# ----> 1 logons_df[logons_df["Account"].endswith("MSTICAdmin")]
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5460             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5461                 return self[name]
# -> 5462             return object.__getattribute__(self, name)
#    5463
#    5464     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'endswith'

# %%
logons_df["Account"]
# Out:
# 0              NT AUTHORITY\SYSTEM
# 1       MSTICAlertsWin1\MSTICAdmin
# 2       MSTICAlertsWin1\MSTICAdmin
# 3       MSTICAlertsWin1\MSTICAdmin
# 4       MSTICAlertsWin1\MSTICAdmin
# 5              NT AUTHORITY\SYSTEM
# 6              NT AUTHORITY\SYSTEM
# 7              NT AUTHORITY\SYSTEM
# 8              NT AUTHORITY\SYSTEM
# 9              NT AUTHORITY\SYSTEM
# 10               NT AUTHORITY\IUSR
# 11             NT AUTHORITY\SYSTEM
# 12             NT AUTHORITY\SYSTEM
# 13             NT AUTHORITY\SYSTEM
# 14    NT AUTHORITY\NETWORK SERVICE
# 15            Window Manager\DWM-1
# 16            Window Manager\DWM-1
# 17      NT AUTHORITY\LOCAL SERVICE
# 18             NT AUTHORITY\SYSTEM
# 19             NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %% [markdown]
# ### We need to tell pandas to apply string operation as a vector to the series
#
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df[df[<i>column</i>].<b>str</b>.contains(<i>str_expr</i>)]
# </p>

# %%
logons_df[logons_df["Account"].str.endswith("MSTICAdmin")]
# Out:
#                         Account  EventID           TimeGenerated  \
# 150  MSTICAlertsWin1\MSTICAdmin     4624 2019-02-15 03:57:02.593
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 150  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#     TargetUserName TargetDomainName  \
# 150     MSTICAdmin  MSTICAlertsWin1
#
#                                     TargetUserSid TargetLogonId  LogonType  \
# 150  S-1-5-21-996632719-2361334927-4038480536-500     0x109c408         10
#
#            IpAddress  WorkstationName          TimeCreatedUtc
# 150  131.107.147.209  MSTICAlertsWin1 2019-02-15 03:57:02.593

# %% [markdown]
# ## Multiple conditions
# <p style="font-family:consolas; font-size:15pt; color:green">
# & == AND<br>
# | == OR<br>
# ~ == NOT<br>
# </p>
# <p style="border:solid; font-size:15pt; padding:5pt">
# Always use parentheses around individual expressions in composite logical expressions!
# </p>

# %%
logons_df[
    logons_df["Account"].str.endswith("MSTICAdmin")
]

# We want to add a time expression
t1 = pd.Timestamp("2019-02-12 04:00")
t2 = pd.to_datetime("2019-02-12 05:00")
t1, t2
# Out:
# (Timestamp('2019-02-12 04:00:00'), Timestamp('2019-02-12 05:00:00'))

# %%
logons_df[
    (logons_df["Account"].str.endswith("SYSTEM"))
    &
    (logons_df["TimeGenerated"] >= t1)
    &
    (logons_df["TimeGenerated"] <= t2)
]
# Out:
#                 Account  EventID           TimeGenerated         Computer  \
# 28  NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:11.573  MSTICAlertsWin1
# 12  NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:03.870  MSTICAlertsWin1
# 20  NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:07.463  MSTICAlertsWin1
#
#      SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 28  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 12                 -                 -        S-1-0-0         SYSTEM
# 20  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#    TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 28     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 12     NT AUTHORITY      S-1-5-18         0x3e7          0         -
# 20     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#    WorkstationName          TimeCreatedUtc
# 28               - 2019-02-12 04:40:11.573
# 12               - 2019-02-12 04:40:03.870
# 20               - 2019-02-12 04:40:07.463

# %%
### Without parentheses - `&, |, ~` have higher precedence
logons_df[
    logons_df["Account"].str.contains("MSTICAdmin")
    &
    logons_df["TimeGenerated"] >= t1
    &
    logons_df["TimeGenerated"] <= t2
]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8680/3190794489.py in <module>
#       3     logons_df["Account"].str.contains("MSTICAdmin")
#       4     &
# ----> 5     logons_df["TimeGenerated"] >= t1
#       6     &
#       7     logons_df["TimeGenerated"] <= t2
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\arraylike.py in __and__(self, other)
#      57     @unpack_zerodim_and_defer("__and__")
#      58     def __and__(self, other):
# ---> 59         return self._logical_method(other, operator.and_)
#      60
#      61     @unpack_zerodim_and_defer("__rand__")
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py in _logical_method(self, other, op)
#    4957         rvalues = extract_array(other, extract_numpy=True)
#    4958
# -> 4959         res_values = ops.logical_op(lvalues, rvalues, op)
#    4960         return self._construct_result(res_values, name=res_name)
#    4961
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\core\ops\array_ops.py in logical_op(left, right, op)
#     338     if should_extension_dispatch(lvalues, rvalues):
#     339         # Call the method on lvalues
# --> 340         res_values = op(lvalues, rvalues)
#     341
#     342     else:
#
# TypeError: unsupported operand type(s) for &: 'numpy.ndarray' and 'DatetimeArray'

# %%
logons_df[
    (logons_df["LogonType"].isin([0, 3, 5]))
    &
    (logons_df["TimeGenerated"].dt.hour >= 4)
    &
    (logons_df["TimeGenerated"].dt.day == 12)
]
# Out:
#                  Account  EventID           TimeGenerated         Computer  \
# 28   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:11.573  MSTICAlertsWin1
# 133  NT AUTHORITY\SYSTEM     4624 2019-02-12 22:13:39.547  MSTICAlertsWin1
# 12   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:03.870  MSTICAlertsWin1
# 20   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:07.463  MSTICAlertsWin1
# 108  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:53:36.280  MSTICAlertsWin1
# 128  NT AUTHORITY\SYSTEM     4624 2019-02-12 22:07:40.680  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 28   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 133  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 12                  -                 -        S-1-0-0         SYSTEM
# 20   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 108  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 128  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 28      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 133     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 12      NT AUTHORITY      S-1-5-18         0x3e7          0         -
# 20      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 108     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 128     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 28                - 2019-02-12 04:40:11.573
# 133               - 2019-02-12 22:13:39.547
# 12                - 2019-02-12 04:40:03.870
# 20                - 2019-02-12 04:40:07.463
# 108               - 2019-02-12 21:53:36.280
# 128               - 2019-02-12 22:07:40.680

# %% [markdown]
# ### Boolean indexes are Pandas series - you can save and re-use

# %%
# create individual criteria
logon_type_3 = logons_df["LogonType"].isin([0, 3, 5])
hour_4 = logons_df["TimeGenerated"].dt.hour >= 4
day_12 = logons_df["TimeGenerated"].dt.day == 12

# %%
# use them together to filter
logons_df[logon_type_3 & hour_4 & day_12]
# Out:
#                  Account  EventID           TimeGenerated         Computer  \
# 28   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:11.573  MSTICAlertsWin1
# 133  NT AUTHORITY\SYSTEM     4624 2019-02-12 22:13:39.547  MSTICAlertsWin1
# 12   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:03.870  MSTICAlertsWin1
# 20   NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:07.463  MSTICAlertsWin1
# 108  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:53:36.280  MSTICAlertsWin1
# 128  NT AUTHORITY\SYSTEM     4624 2019-02-12 22:07:40.680  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 28   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 133  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 12                  -                 -        S-1-0-0         SYSTEM
# 20   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 108  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 128  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 28      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 133     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 12      NT AUTHORITY      S-1-5-18         0x3e7          0         -
# 20      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 108     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 128     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 28                - 2019-02-12 04:40:11.573
# 133               - 2019-02-12 22:13:39.547
# 12                - 2019-02-12 04:40:03.870
# 20                - 2019-02-12 04:40:07.463
# 108               - 2019-02-12 21:53:36.280
# 128               - 2019-02-12 22:07:40.680

# %% [markdown]
# ### List of pandas `str` and `dt` (datetime) accessor functions
#
# [https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary](https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary)

# %%
str_funcs = [func for func in dir(logons_df["Account"].str) if not func.startswith("_")]
print("Pandas 'str' functions")
print("----------------------")
print(", ".join(str_funcs))
print("\nRead more here")
print("https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary")
dt_funcs = [func for func in dir(logons_df["TimeGenerated"].dt) if not func.startswith("_")]
print("\nPandas 'dt' (datetime) functions")
print("----------------------------------")
print(", ".join(dt_funcs))
# Out:
# Pandas 'str' functions
# ----------------------
# capitalize, casefold, cat, center, contains, count, decode, encode, endswith, extract, extractall, find, findall, fullmatch, get, get_dummies, index, isalnum, isalpha, isdecimal, isdigit, islower, isnumeric, isspace, istitle, isupper, join, len, ljust, lower, lstrip, match, normalize, pad, partition, repeat, replace, rfind, rindex, rjust, rpartition, rsplit, rstrip, slice, slice_replace, split, startswith, strip, swapcase, title, translate, upper, wrap, zfill
#
# Read more here
# https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary
#
# Pandas 'dt' (datetime) functions
# ----------------------------------
# ceil, date, day, day_name, day_of_week, day_of_year, dayofweek, dayofyear, days_in_month, daysinmonth, floor, freq, hour, is_leap_year, is_month_end, is_month_start, is_quarter_end, is_quarter_start, is_year_end, is_year_start, isocalendar, microsecond, minute, month, month_name, nanosecond, normalize, quarter, round, second, strftime, time, timetz, to_period, to_pydatetime, tz, tz_convert, tz_localize, week, weekday, weekofyear, year

# %% [markdown]
# ## `isin` operator/function

# %%
logons_df[logons_df["TargetUserName"].isin(["MSTICAdmin", "SYSTEM"])].head()
# Out:
#                  Account  EventID           TimeGenerated         Computer  \
# 55   NT AUTHORITY\SYSTEM     4624 2019-02-14 04:12:44.970  MSTICAlertsWin1
# 69   NT AUTHORITY\SYSTEM     4624 2019-02-13 22:08:46.537  MSTICAlertsWin1
# 43   NT AUTHORITY\SYSTEM     4624 2019-02-10 20:03:29.680  MSTICAlertsWin1
# 107  NT AUTHORITY\SYSTEM     4624 2019-02-13 20:08:47.880  MSTICAlertsWin1
# 94   NT AUTHORITY\SYSTEM     4624 2019-02-13 20:09:41.273  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 55   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 69   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 43   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 107  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 94   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 55      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 69      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 43      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 107     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 94      NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 55                - 2019-02-14 04:12:44.970
# 69                - 2019-02-13 22:08:46.537
# 43                - 2019-02-10 20:03:29.680
# 107               - 2019-02-13 20:08:47.880
# 94                - 2019-02-13 20:09:41.273

# %% [markdown]
# ## pandas `query` function
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.query(query_str)
# </p>
# Useful for simpler queries - and definitely nicer-looking but some limitations - only simple operators supported.
#
# Good for quick things but I prefer the boolean stuff for more complex queries.
#
# To reference Python variables prefix the variable name with "@" (see second example)

# %%
logons_df.query("TargetUserName == 'MSTICAdmin' and TargetLogonId == '0xc913737'")

logons_df.query("TargetUserName == 'MSTICAdmin' and TimeGenerated > @t1")
# Out:
#                         Account  EventID           TimeGenerated  \
# 150  MSTICAlertsWin1\MSTICAdmin     4624 2019-02-15 03:57:02.593
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 150  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#     TargetUserName TargetDomainName  \
# 150     MSTICAdmin  MSTICAlertsWin1
#
#                                     TargetUserSid TargetLogonId  LogonType  \
# 150  S-1-5-21-996632719-2361334927-4038480536-500     0x109c408         10
#
#            IpAddress  WorkstationName          TimeCreatedUtc
# 150  131.107.147.209  MSTICAlertsWin1 2019-02-15 03:57:02.593

# %% [markdown]
# The output of `query` is a DataFrame so you can also easily combine with boolean indexing

# %%
(
    logons_df
    [logons_df["Account"].str.match("MST.*")]
    .query("LogonType == 10 and TimeGenerated > @t1")
)
# Out:
#                         Account  EventID           TimeGenerated  \
# 150  MSTICAlertsWin1\MSTICAdmin     4624 2019-02-15 03:57:02.593
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 150  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#     TargetUserName TargetDomainName  \
# 150     MSTICAdmin  MSTICAlertsWin1
#
#                                     TargetUserSid TargetLogonId  LogonType  \
# 150  S-1-5-21-996632719-2361334927-4038480536-500     0x109c408         10
#
#            IpAddress  WorkstationName          TimeCreatedUtc
# 150  131.107.147.209  MSTICAlertsWin1 2019-02-15 03:57:02.593

# %% [markdown]
# ### Combing Column Select and filter

# %%
(
    logons_df[logons_df["Account"].str.contains("MSTICAdmin")]
    [["Account", "TimeGenerated"]]
)
# Out:
#                       Account           TimeGenerated
# 1  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:37:25.340
# 2  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:37:27.997
# 3  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:38:16.550
# 4  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:38:21.370

# %% [markdown]
# # Sorting and removing duplicates
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.sort_values(<i>column</i>|<i>[column_list]</i>], [ascending=True|False])
# </p>

# %%
logons_df.sort_values("TimeGenerated", ascending=False).head(3)
# Out:
#                                TenantId              Account  EventID  \
# 0  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 6  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 5  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
#
#             TimeGenerated                      SourceComputerId  \
# 0 2019-02-12 04:56:34.307  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 6 2019-02-12 04:50:18.660  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 5 2019-02-12 04:50:09.713  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 0  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 6  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 5  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#   TargetUserName TargetDomainName TargetUserSid TargetLogonId  \
# 0         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 6         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 5         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
#
#   LogonProcessName  LogonType AuthenticationPackageName Status IpAddress  \
# 0         Advapi            5                 Negotiate                -
# 6         Advapi            5                 Negotiate                -
# 5         Advapi            5                 Negotiate                -
#
#   WorkstationName          TimeCreatedUtc
# 0               - 2019-02-12 04:56:34.307
# 6               - 2019-02-12 04:50:18.660
# 5               - 2019-02-12 04:50:09.713

# %% [markdown]
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.drop_duplicates()
# </p>

# %%
(
    logons_df[["Account", "LogonType"]]
    .drop_duplicates()
    .sort_values("Account")
)
# Out:
#                           Account  LogonType
# 150    MSTICAlertsWin1\MSTICAdmin         10
# 72   NT AUTHORITY\NETWORK SERVICE          5
# 55            NT AUTHORITY\SYSTEM          5
# 12            NT AUTHORITY\SYSTEM          0
# 157          Window Manager\DWM-2          2

# %% [markdown]
# ---
# # Grouping and Aggregation
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.groupby(<i>column</i>|<i>[column_list]</i>])
# </p>

# %%
logons_df.groupby("Account")

# %% [markdown]
# ### You need an aggregator (or iterator) make use of grouping
#
# Add an aggregation function

# %%
logons_df.groupby("Account").count()  # Yuk!
# Out:
#                               EventID  TimeGenerated  Computer  \
# Account
# MSTICAlertsWin1\MSTICAdmin          1              1         1
# NT AUTHORITY\NETWORK SERVICE        1              1         1
# NT AUTHORITY\SYSTEM                16             16        16
# Window Manager\DWM-2                2              2         2
#
#                               SubjectUserName  SubjectDomainName  \
# Account
# MSTICAlertsWin1\MSTICAdmin                  1                  1
# NT AUTHORITY\NETWORK SERVICE                1                  1
# NT AUTHORITY\SYSTEM                        16                 16
# Window Manager\DWM-2                        2                  2
#
#                               SubjectUserSid  TargetUserName  \
# Account
# MSTICAlertsWin1\MSTICAdmin                 1               1
# NT AUTHORITY\NETWORK SERVICE               1               1
# NT AUTHORITY\SYSTEM                       16              16
# Window Manager\DWM-2                       2               2
#
#                               TargetDomainName  TargetUserSid  TargetLogonId  \
# Account
# MSTICAlertsWin1\MSTICAdmin                   1              1              1
# NT AUTHORITY\NETWORK SERVICE                 1              1              1
# NT AUTHORITY\SYSTEM                         16             16             16
# Window Manager\DWM-2                         2              2              2
#
#                               LogonType  IpAddress  WorkstationName  \
# Account
# MSTICAlertsWin1\MSTICAdmin            1          1                1
# NT AUTHORITY\NETWORK SERVICE          1          1                1
# NT AUTHORITY\SYSTEM                  16         16               16
# Window Manager\DWM-2                  2          2                2
#
#                               TimeCreatedUtc
# Account
# MSTICAlertsWin1\MSTICAdmin                 1
# NT AUTHORITY\NETWORK SERVICE               1
# NT AUTHORITY\SYSTEM                       16
# Window Manager\DWM-2                       2

# %% [markdown]
# Tidy up by limiting and renaming columns

# %%
(
    logons_df[["TimeGenerated", "Account"]]
    .groupby("Account")
    .count()
    .rename(columns={"TimeGenerated": "LogonCount"})
)
# Out:
#                               LogonCount
# Account
# MSTICAlertsWin1\MSTICAdmin             1
# NT AUTHORITY\NETWORK SERVICE           1
# NT AUTHORITY\SYSTEM                   16
# Window Manager\DWM-2                   2

# %% [markdown]
# ## Iterating over groups - `groupby` returns an iterable

# %%
print("Numbers of rows in each group:")

for name, logon_group in logons_df.groupby("Account"):
    print(name, type(logon_group), "size", logon_group.shape)
# Out:
# Numbers of rows in each group:
# MSTICAlertsWin1\MSTICAdmin <class 'pandas.core.frame.DataFrame'> size (1, 15)
# NT AUTHORITY\NETWORK SERVICE <class 'pandas.core.frame.DataFrame'> size (1, 15)
# NT AUTHORITY\SYSTEM <class 'pandas.core.frame.DataFrame'> size (16, 15)
# Window Manager\DWM-2 <class 'pandas.core.frame.DataFrame'> size (2, 15)

# %%
print("\nCollect individual group DFs in dictionary")
df_dict = {name: df for name, df in logons_df.groupby("Account")}

print(df_dict.keys())
df_dict["NT AUTHORITY\SYSTEM"].head()
# Out:
# Collect individual group DFs in dictionary
# dict_keys(['MSTICAlertsWin1\\MSTICAdmin', 'NT AUTHORITY\\NETWORK SERVICE', 'NT AUTHORITY\\SYSTEM', 'Window Manager\\DWM-2'])
#                  Account  EventID           TimeGenerated         Computer  \
# 55   NT AUTHORITY\SYSTEM     4624 2019-02-14 04:12:44.970  MSTICAlertsWin1
# 69   NT AUTHORITY\SYSTEM     4624 2019-02-13 22:08:46.537  MSTICAlertsWin1
# 43   NT AUTHORITY\SYSTEM     4624 2019-02-10 20:03:29.680  MSTICAlertsWin1
# 107  NT AUTHORITY\SYSTEM     4624 2019-02-13 20:08:47.880  MSTICAlertsWin1
# 94   NT AUTHORITY\SYSTEM     4624 2019-02-13 20:09:41.273  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 55   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 69   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 43   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 107  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 94   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 55      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 69      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 43      NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 107     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 94      NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 55                - 2019-02-14 04:12:44.970
# 69                - 2019-02-13 22:08:46.537
# 43                - 2019-02-10 20:03:29.680
# 107               - 2019-02-13 20:08:47.880
# 94                - 2019-02-13 20:09:41.273

# %% [markdown]
# ## Grouping with Multiple aggregation functions
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# .agg({"Column_1": "agg_func", "Column_2": "agg_func"})
# </p>

# %%
import numpy as np
(
    logons_df[["TimeGenerated", "LogonType", "Account"]]
    .groupby("Account")
    .agg({"TimeGenerated": "max", "LogonType": np.unique})
    .rename(columns={"TimeGenerated": "LastTime"})
)
# Out:
#                                             LastTime LogonType
# Account
# MSTICAlertsWin1\MSTICAdmin   2019-02-15 03:57:02.593        10
# NT AUTHORITY\NETWORK SERVICE 2019-02-14 04:20:54.630         5
# NT AUTHORITY\SYSTEM          2019-02-14 04:51:37.183    [0, 5]
# Window Manager\DWM-2         2019-02-15 03:57:01.903         2

# %% [markdown]
# ## Grouping with multiple columns
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# .groupby(["Account", "LogonType"])
# </p>

# %%
(
    logons_full_df[["TimeGenerated", "EventID", "Account", "LogonType"]]      # DF input fields
    .groupby(["Account", "LogonType"])                                        # Grouping fields
    .agg({"TimeGenerated": "max", "EventID": "count"})                        # aggregate operations
    .rename(columns={"TimeGenerated": "LastTime", "EventID": "Count"})        # Rename output
)
# Out:
#                                                       LastTime  Count
# Account                      LogonType
# MSTICAlertsWin1\MSTICAdmin   3         2019-02-15 03:57:00.207      8
#                              4         2019-02-14 11:51:37.603      8
#                              10        2019-02-15 03:57:02.593      2
# MSTICAlertsWin1\ian          2         2019-02-12 20:29:51.030      2
#                              3         2019-02-15 03:56:34.440      5
#                              4         2019-02-12 20:41:17.310      1
# NT AUTHORITY\IUSR            5         2019-02-14 04:20:56.110      2
# NT AUTHORITY\LOCAL SERVICE   5         2019-02-14 04:20:54.803      2
# NT AUTHORITY\NETWORK SERVICE 5         2019-02-14 04:20:54.630      2
# NT AUTHORITY\SYSTEM          0         2019-02-14 04:20:54.370      2
#                              5         2019-02-15 11:51:37.597    120
# Window Manager\DWM-1         2         2019-02-14 04:20:54.773      4
# Window Manager\DWM-2         2         2019-02-15 03:57:01.903      6

# %% [markdown]
# ## Using pd.Grouper to group by time interval
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# .groupby(["Account", pd.Grouper(key="TimeGenerated", freq="1D")])
# </p>

# %%
(
    logons_full_df[["TimeGenerated", "EventID", "Account", "LogonType"]]
    .groupby(["Account", pd.Grouper(key="TimeGenerated", freq="1D")])
    .agg({"TimeGenerated": "max", "EventID": "count"})
    .rename(columns={"TimeGenerated": "LastTime", "EventID": "Count"})
)
# Out:
#                                                           LastTime  Count
# Account                      TimeGenerated
# MSTICAlertsWin1\MSTICAdmin   2019-02-09    2019-02-09 23:26:47.700      1
#                              2019-02-11    2019-02-11 22:47:53.750      4
#                              2019-02-12    2019-02-12 20:19:44.767      7
#                              2019-02-13    2019-02-13 23:07:23.823      2
#                              2019-02-14    2019-02-14 11:51:37.603      1
#                              2019-02-15    2019-02-15 03:57:02.593      3
# MSTICAlertsWin1\ian          2019-02-12    2019-02-12 20:41:17.310      3
#                              2019-02-13    2019-02-13 00:57:37.187      3
#                              2019-02-15    2019-02-15 03:56:34.440      2
# NT AUTHORITY\IUSR            2019-02-12    2019-02-12 04:40:12.360      1
#                              2019-02-14    2019-02-14 04:20:56.110      1
# NT AUTHORITY\LOCAL SERVICE   2019-02-12    2019-02-12 04:40:04.573      1
#                              2019-02-14    2019-02-14 04:20:54.803      1
# NT AUTHORITY\NETWORK SERVICE 2019-02-12    2019-02-12 04:40:04.207      1
#                              2019-02-14    2019-02-14 04:20:54.630      1
# NT AUTHORITY\SYSTEM          2019-02-09    2019-02-09 12:35:51.683      2
#                              2019-02-10    2019-02-10 21:47:21.503     11
#                              2019-02-11    2019-02-11 09:59:02.593      2
#                              2019-02-12    2019-02-12 22:20:59.200     53
#                              2019-02-13    2019-02-13 22:08:46.537     10
#                              2019-02-14    2019-02-14 14:51:37.637     33
#                              2019-02-15    2019-02-15 11:51:37.597     11
# Window Manager\DWM-1         2019-02-12    2019-02-12 04:40:04.483      2
#                              2019-02-14    2019-02-14 04:20:54.773      2
# Window Manager\DWM-2         2019-02-12    2019-02-12 22:22:21.240      4
#                              2019-02-15    2019-02-15 03:57:01.903      2

# %% [markdown]
# ---
# # Adding and removing columns
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# df[<i>column_name</i>] = <i>expr</i>
# </p>

# %%
new_df = logons_df.copy()

# Adding a static value
new_df["StaticValue"] = "A logon"
# Extracting a substring (there are several ways to do this)
new_df["NTDomain"] = new_df.Account.str.split("\\", 1, expand=True)[0]
# Transforming using an accessor
new_df["DayOfWeek"] = new_df.TimeGenerated.dt.day_name()
# Arithmetic calculations
new_df["BigEventID"] = new_df.EventID * 1000000
new_df["SameTimeTomorrow"] = new_df.TimeGenerated + pd.Timedelta("1D")

print("Old")
display(logons_df[["Account", "TimeGenerated", "EventID"]].head())
print("New")
new_df[[
    "Account", "TimeGenerated", "StaticValue", "NTDomain", "DayOfWeek", "BigEventID", "SameTimeTomorrow"
]].head()
# Out:
# Old
#                  Account           TimeGenerated  EventID
# 55   NT AUTHORITY\SYSTEM 2019-02-14 04:12:44.970     4624
# 69   NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537     4624
# 43   NT AUTHORITY\SYSTEM 2019-02-10 20:03:29.680     4624
# 107  NT AUTHORITY\SYSTEM 2019-02-13 20:08:47.880     4624
# 94   NT AUTHORITY\SYSTEM 2019-02-13 20:09:41.273     4624
# New
#                  Account           TimeGenerated StaticValue      NTDomain  \
# 55   NT AUTHORITY\SYSTEM 2019-02-14 04:12:44.970     A logon  NT AUTHORITY
# 69   NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537     A logon  NT AUTHORITY
# 43   NT AUTHORITY\SYSTEM 2019-02-10 20:03:29.680     A logon  NT AUTHORITY
# 107  NT AUTHORITY\SYSTEM 2019-02-13 20:08:47.880     A logon  NT AUTHORITY
# 94   NT AUTHORITY\SYSTEM 2019-02-13 20:09:41.273     A logon  NT AUTHORITY
#
#      DayOfWeek  BigEventID        SameTimeTomorrow
# 55    Thursday  4624000000 2019-02-15 04:12:44.970
# 69   Wednesday  4624000000 2019-02-14 22:08:46.537
# 43      Sunday  4624000000 2019-02-11 20:03:29.680
# 107  Wednesday  4624000000 2019-02-14 20:08:47.880
# 94   Wednesday  4624000000 2019-02-14 20:09:41.273

# %% [markdown]
# ## `assign` function
#
# Note this introduces a new column to the **output** - it does not update the dataframe.
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.assign(NewColumn=<i>expr</i>)
# </p>

# %%
(
    new_df[["Account", "TimeGenerated", "DayOfWeek", "SameTimeTomorrow"]]
    .assign(
        SameTimeLastWeek=new_df.TimeGenerated - pd.Timedelta("1W"),
        When=new_df.StaticValue.str.cat(new_df.DayOfWeek, sep=" happened on ")
    )
)
# Out:
#                           Account           TimeGenerated  DayOfWeek  \
# 55            NT AUTHORITY\SYSTEM 2019-02-14 04:12:44.970   Thursday
# 69            NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537  Wednesday
# 43            NT AUTHORITY\SYSTEM 2019-02-10 20:03:29.680     Sunday
# 107           NT AUTHORITY\SYSTEM 2019-02-13 20:08:47.880  Wednesday
# 94            NT AUTHORITY\SYSTEM 2019-02-13 20:09:41.273  Wednesday
# 28            NT AUTHORITY\SYSTEM 2019-02-12 04:40:11.573    Tuesday
# 133           NT AUTHORITY\SYSTEM 2019-02-12 22:13:39.547    Tuesday
# 157          Window Manager\DWM-2 2019-02-15 03:57:01.903     Friday
# 85            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.663   Thursday
# 64            NT AUTHORITY\SYSTEM 2019-02-13 21:10:58.540  Wednesday
# 72   NT AUTHORITY\NETWORK SERVICE 2019-02-14 04:20:54.630   Thursday
# 150    MSTICAlertsWin1\MSTICAdmin 2019-02-15 03:57:02.593     Friday
# 99           Window Manager\DWM-2 2019-02-12 22:22:21.240    Tuesday
# 67            NT AUTHORITY\SYSTEM 2019-02-14 04:51:37.183   Thursday
# 12            NT AUTHORITY\SYSTEM 2019-02-12 04:40:03.870    Tuesday
# 88            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.700   Thursday
# 20            NT AUTHORITY\SYSTEM 2019-02-12 04:40:07.463    Tuesday
# 108           NT AUTHORITY\SYSTEM 2019-02-12 21:53:36.280    Tuesday
# 128           NT AUTHORITY\SYSTEM 2019-02-12 22:07:40.680    Tuesday
# 71            NT AUTHORITY\SYSTEM 2019-02-14 04:20:54.530   Thursday
#
#            SameTimeTomorrow        SameTimeLastWeek  \
# 55  2019-02-15 04:12:44.970 2019-02-07 04:12:44.970
# 69  2019-02-14 22:08:46.537 2019-02-06 22:08:46.537
# 43  2019-02-11 20:03:29.680 2019-02-03 20:03:29.680
# 107 2019-02-14 20:08:47.880 2019-02-06 20:08:47.880
# 94  2019-02-14 20:09:41.273 2019-02-06 20:09:41.273
# 28  2019-02-13 04:40:11.573 2019-02-05 04:40:11.573
# 133 2019-02-13 22:13:39.547 2019-02-05 22:13:39.547
# 157 2019-02-16 03:57:01.903 2019-02-08 03:57:01.903
# 85  2019-02-15 04:20:55.663 2019-02-07 04:20:55.663
# 64  2019-02-14 21:10:58.540 2019-02-06 21:10:58.540
# 72  2019-02-15 04:20:54.630 2019-02-07 04:20:54.630
# 150 2019-02-16 03:57:02.593 2019-02-08 03:57:02.593
# 99  2019-02-13 22:22:21.240 2019-02-05 22:22:21.240
# 67  2019-02-15 04:51:37.183 2019-02-07 04:51:37.183
# 12  2019-02-13 04:40:03.870 2019-02-05 04:40:03.870
# 88  2019-02-15 04:20:55.700 2019-02-07 04:20:55.700
# 20  2019-02-13 04:40:07.463 2019-02-05 04:40:07.463
# 108 2019-02-13 21:53:36.280 2019-02-05 21:53:36.280
# 128 2019-02-13 22:07:40.680 2019-02-05 22:07:40.680
# 71  2019-02-15 04:20:54.530 2019-02-07 04:20:54.530
#
#                               When
# 55    A logon happened on Thursday
# 69   A logon happened on Wednesday
# 43      A logon happened on Sunday
# 107  A logon happened on Wednesday
# 94   A logon happened on Wednesday
# 28     A logon happened on Tuesday
# 133    A logon happened on Tuesday
# 157     A logon happened on Friday
# 85    A logon happened on Thursday
# 64   A logon happened on Wednesday
# 72    A logon happened on Thursday
# 150     A logon happened on Friday
# 99     A logon happened on Tuesday
# 67    A logon happened on Thursday
# 12     A logon happened on Tuesday
# 88    A logon happened on Thursday
# 20     A logon happened on Tuesday
# 108    A logon happened on Tuesday
# 128    A logon happened on Tuesday
# 71    A logon happened on Thursday

# %%
new_df.columns
# Out:
# Index(['Account', 'EventID', 'TimeGenerated', 'Computer', 'SubjectUserName',
#        'SubjectDomainName', 'SubjectUserSid', 'TargetUserName',
#        'TargetDomainName', 'TargetUserSid', 'TargetLogonId', 'LogonType',
#        'IpAddress', 'WorkstationName', 'TimeCreatedUtc', 'StaticValue',
#        'NTDomain', 'DayOfWeek', 'BigEventID', 'SameTimeTomorrow'],
#       dtype='object')

# %% [markdown]
# ### Drop columns
# <p style="font-family:consolas; font-size:15pt; color:green">
# df.drop(columns=[<i>column_list</i>])<br><br>
# df.drop(columns=[<i>column_list</i>], inplace=True) <i># Beware!</i><br>
# </p>

# %%
(
    new_df[["Account", "TimeGenerated", "StaticValue", "NTDomain", "DayOfWeek"]]
    .head()
    .drop(columns=["NTDomain"])
)
# Out:
#                  Account           TimeGenerated StaticValue  DayOfWeek
# 55   NT AUTHORITY\SYSTEM 2019-02-14 04:12:44.970     A logon   Thursday
# 69   NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537     A logon  Wednesday
# 43   NT AUTHORITY\SYSTEM 2019-02-10 20:03:29.680     A logon     Sunday
# 107  NT AUTHORITY\SYSTEM 2019-02-13 20:08:47.880     A logon  Wednesday
# 94   NT AUTHORITY\SYSTEM 2019-02-13 20:09:41.273     A logon  Wednesday

# %% [markdown]
# ## Some other quick ways of filtering out (in) columns
# <p style="font-family:consolas; font-size:15pt; color:green">
# .filter(regex="Target.*", axis=1)
# </p>

# %%
logons_df.filter(regex="Target.*", axis=1).head()
# Out:
#     TargetUserName TargetDomainName TargetUserSid TargetLogonId
# 67          SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 118         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 149         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 76          SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 51          SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7

# %% [markdown]
# Filter by Data Type
# <p style="font-family:consolas; font-size:15pt; color:green">
# .select_dtypes(include="datetime")
# </p>

# %%
logons_df.select_dtypes(include="datetime").head()  # also "number", "object"
# Out:
#               TimeGenerated          TimeCreatedUtc
# 67  2019-02-14 04:51:37.183 2019-02-14 04:51:37.183
# 118 2019-02-12 21:39:15.897 2019-02-12 21:39:15.897
# 149 2019-02-15 08:51:51.763 2019-02-15 08:51:51.763
# 76  2019-02-14 04:20:54.987 2019-02-14 04:20:54.987
# 51  2019-02-09 12:32:50.220 2019-02-09 12:32:50.220

# %% [markdown]
# ---
# # Simple Joins
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# pd.concat([<i>df_list</i>])
# </p>
#
# (relational joins tomorrow)

# %% [markdown]
# ## Concatenating DFs

# %%
# Extract two DFs from subset of rows
df1 = logons_full_df[0:10]
df2 = logons_full_df[100:120]

print("Dimensions of DFs (rows, cols)")
print("df1:", df1.shape, "df2:", df2.shape)
display(df1.tail(3))
display(df2.tail(3))
# Out:
# Dimensions of DFs (rows, cols)
# df1: (10, 15) df2: (20, 15)
#                Account  EventID           TimeGenerated         Computer  \
# 7  NT AUTHORITY\SYSTEM     4624 2019-02-12 04:43:56.327  MSTICAlertsWin1
# 8  NT AUTHORITY\SYSTEM     4624 2019-02-12 04:44:10.343  MSTICAlertsWin1
# 9  NT AUTHORITY\SYSTEM     4624 2019-02-12 04:40:11.867  MSTICAlertsWin1
#
#     SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 7  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 8  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 9  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#   TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 7     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 8     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 9     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#   WorkstationName          TimeCreatedUtc
# 7               - 2019-02-12 04:43:56.327
# 8               - 2019-02-12 04:44:10.343
# 9               - 2019-02-12 04:40:11.867
#                  Account  EventID           TimeGenerated         Computer  \
# 117  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:49:11.777  MSTICAlertsWin1
# 118  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:39:15.897  MSTICAlertsWin1
# 119  NT AUTHORITY\SYSTEM     4624 2019-02-12 20:11:06.790  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 117  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 118  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 119  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 117     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 118     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 119     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 117               - 2019-02-12 21:49:11.777
# 118               - 2019-02-12 21:39:15.897
# 119               - 2019-02-12 20:11:06.790

# %% [markdown]
# #### Joining rows

# %%
joined_df = pd.concat([df1, df2])

print(joined_df.shape)
joined_df.tail(3)
# Out:
# (30, 15)
#                  Account  EventID           TimeGenerated         Computer  \
# 117  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:49:11.777  MSTICAlertsWin1
# 118  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:39:15.897  MSTICAlertsWin1
# 119  NT AUTHORITY\SYSTEM     4624 2019-02-12 20:11:06.790  MSTICAlertsWin1
#
#       SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 117  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 118  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 119  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#     TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 117     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 118     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 119     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#     WorkstationName          TimeCreatedUtc
# 117               - 2019-02-12 21:49:11.777
# 118               - 2019-02-12 21:39:15.897
# 119               - 2019-02-12 20:11:06.790

# %% [markdown]
# #### `ignore_index=True` causes Python to regenerate a new index
# <p style="font-family:consolas; font-size:15pt; color:green">
# pd.concat(df_list, <b>ignore_index=True</b>)
# </p>

# %%
df_list = [df1, df2]
joined_df = pd.concat(df_list, ignore_index=True)

print(joined_df.shape)
joined_df.tail(3)
# Out:
# (30, 15)
#                 Account  EventID           TimeGenerated         Computer  \
# 27  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:49:11.777  MSTICAlertsWin1
# 28  NT AUTHORITY\SYSTEM     4624 2019-02-12 21:39:15.897  MSTICAlertsWin1
# 29  NT AUTHORITY\SYSTEM     4624 2019-02-12 20:11:06.790  MSTICAlertsWin1
#
#      SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 27  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 28  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 29  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#    TargetDomainName TargetUserSid TargetLogonId  LogonType IpAddress  \
# 27     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 28     NT AUTHORITY      S-1-5-18         0x3e7          5         -
# 29     NT AUTHORITY      S-1-5-18         0x3e7          5         -
#
#    WorkstationName          TimeCreatedUtc
# 27               - 2019-02-12 21:49:11.777
# 28               - 2019-02-12 21:39:15.897
# 29               - 2019-02-12 20:11:06.790

# %% [markdown]
# ## Joining columns (horizontal)
#
# <p style="font-family:consolas; font-size:15pt; color:green">
# pd.concat([df_1, df_2...], <b>axis="columns"</b>)
# </p>

# %%
df_col_1 = logons_full_df[0:10].filter(regex="Subject.*")
df_col_2 = logons_full_df[0:12].filter(regex="Target.*")
print(df_col_1.shape, df_col_2.shape)
display(df_col_1.head())
display(df_col_2.head())
# Out:
# (10, 3) (12, 4)
#     SubjectUserName SubjectDomainName SubjectUserSid
# 0  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 1                 -                 -        S-1-0-0
# 2                 -                 -        S-1-0-0
# 3                 -                 -        S-1-0-0
# 4                 -                 -        S-1-0-0
#   TargetUserName TargetDomainName  \
# 0         SYSTEM     NT AUTHORITY
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
# 3     MSTICAdmin  MSTICAlertsWin1
# 4     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId
# 0                                      S-1-5-18         0x3e7
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
# 3  S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 4  S-1-5-21-996632719-2361334927-4038480536-500     0xc913737

# %%
pd.concat([df_col_1, df_col_2], axis="columns")
# Out:
#      SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 0   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 1                  -                 -        S-1-0-0     MSTICAdmin
# 2                  -                 -        S-1-0-0     MSTICAdmin
# 3                  -                 -        S-1-0-0     MSTICAdmin
# 4                  -                 -        S-1-0-0     MSTICAdmin
# 5   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 6   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 7   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 8   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 9   MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 10               NaN               NaN            NaN           IUSR
# 11               NaN               NaN            NaN         SYSTEM
#
#    TargetDomainName                                 TargetUserSid  \
# 0      NT AUTHORITY                                      S-1-5-18
# 1   MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 2   MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 3   MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 4   MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500
# 5      NT AUTHORITY                                      S-1-5-18
# 6      NT AUTHORITY                                      S-1-5-18
# 7      NT AUTHORITY                                      S-1-5-18
# 8      NT AUTHORITY                                      S-1-5-18
# 9      NT AUTHORITY                                      S-1-5-18
# 10     NT AUTHORITY                                      S-1-5-17
# 11     NT AUTHORITY                                      S-1-5-18
#
#    TargetLogonId
# 0          0x3e7
# 1      0xc90e957
# 2      0xc90ea44
# 3      0xc912d62
# 4      0xc913737
# 5          0x3e7
# 6          0x3e7
# 7          0x3e7
# 8          0x3e7
# 9          0x3e7
# 10         0x3e3
# 11         0x3e7

# %% [markdown]
# ---
#
# # Statistics 101 with Pandas [Jose]

# %% [markdown]
# ---
#
# # End of Session
#
# ---
#
# # Resources

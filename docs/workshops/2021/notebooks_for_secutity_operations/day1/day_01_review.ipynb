# %%
import pandas as pd

# %%
help(pd.DataFrame)

# %%
# We're going to read another data set in with more variety
logons_full_df = pd.read_pickle("../data/host_logons.pkl")
net_full_df = pd.read_pickle("../data/az_net_comms_df.pkl")

# also create a demo version with just 3 rows
logons_df = logons_full_df.sample(20)
logons_df.head(5)
# Out:
#                                  TenantId                     Account  \
# 13   52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 115  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 124  52b1ab41-869e-4138-9e40-2a4457f09bf0         MSTICAlertsWin1\ian
# 138  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
# 153  52b1ab41-869e-4138-9e40-2a4457f09bf0         MSTICAlertsWin1\ian
#
#      EventID           TimeGenerated                      SourceComputerId  \
# 13      4624 2019-02-12 04:40:04.083  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 115     4624 2019-02-12 21:43:25.113  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 124     4624 2019-02-12 20:41:17.310  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 138     4624 2019-02-12 20:19:41.937  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 153     4624 2019-02-15 03:56:32.210  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 13   MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 115  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 124  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 138  MSTICAlertsWin1                 -                 -        S-1-0-0
# 153  MSTICAlertsWin1                 -                 -        S-1-0-0
#
#     TargetUserName TargetDomainName  \
# 13          SYSTEM     NT AUTHORITY
# 115         SYSTEM     NT AUTHORITY
# 124            ian  MSTICAlertsWin1
# 138     MSTICAdmin  MSTICAlertsWin1
# 153            ian  MSTICAlertsWin1
#
#                                      TargetUserSid TargetLogonId  \
# 13                                        S-1-5-18         0x3e7
# 115                                       S-1-5-18         0x3e7
# 124  S-1-5-21-996632719-2361334927-4038480536-1120      0x7ad58d
# 138   S-1-5-21-996632719-2361334927-4038480536-500      0x2da7cd
# 153  S-1-5-21-996632719-2361334927-4038480536-1120     0x10957b1
#
#     LogonProcessName  LogonType AuthenticationPackageName Status  \
# 13          Advapi            5                 Negotiate
# 115         Advapi            5                 Negotiate
# 124         Advapi            4                 Negotiate
# 138         NtLmSsp           3                      NTLM
# 153         NtLmSsp           3                      NTLM
#
#            IpAddress  WorkstationName          TimeCreatedUtc
# 13                 -                - 2019-02-12 04:40:04.083
# 115                -                - 2019-02-12 21:43:25.113
# 124                -  MSTICAlertsWin1 2019-02-12 20:41:17.310
# 138  131.107.147.209   IANHELLE-DEV17 2019-02-12 20:19:41.937
# 153  131.107.147.209   IANHELLE-DEV17 2019-02-15 03:56:32.210

# %% [markdown]
# ### Rows and Columns of a DataFrame are pandas *Series*

# %%
print(type(logons_df.iloc[0]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
print("logons_df", type(logons_df))
print("logons_df.Account", type(logons_df.Account)) # "Account" row
print("logons_df.iloc[0])", type(logons_df.iloc[0])) # First row

# At the intersection of a row and column we get a simple type - the cell content
print("logons_df.iloc[0].Account", type(logons_df.iloc[0].Account), logons_df.iloc[0].Account)
# Out:
# logons_df <class 'pandas.core.frame.DataFrame'>
# logons_df.Account <class 'pandas.core.series.Series'>
# logons_df.iloc[0]) <class 'pandas.core.series.Series'>
# logons_df.iloc[0].Account <class 'str'> NT AUTHORITY\SYSTEM

# %% [markdown]
# ### What does a series look like?

# %%
# Column
logons_df.Account
# Out:
# 13              NT AUTHORITY\SYSTEM
# 115             NT AUTHORITY\SYSTEM
# 124             MSTICAlertsWin1\ian
# 138      MSTICAlertsWin1\MSTICAdmin
# 153             MSTICAlertsWin1\ian
# 52              NT AUTHORITY\SYSTEM
# 44              NT AUTHORITY\SYSTEM
# 134             NT AUTHORITY\SYSTEM
# 10                NT AUTHORITY\IUSR
# 65              NT AUTHORITY\SYSTEM
# 51              NT AUTHORITY\SYSTEM
# 91              NT AUTHORITY\SYSTEM
# 14     NT AUTHORITY\NETWORK SERVICE
# 73             Window Manager\DWM-1
# 41              NT AUTHORITY\SYSTEM
# 77              NT AUTHORITY\SYSTEM
# 117             NT AUTHORITY\SYSTEM
# 105             NT AUTHORITY\SYSTEM
# 160             NT AUTHORITY\SYSTEM
# 69              NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %%
# Row
logons_df.iloc[0]
# Out:
# TenantId                     52b1ab41-869e-4138-9e40-2a4457f09bf0
# Account                                       NT AUTHORITY\SYSTEM
# EventID                                                      4624
# TimeGenerated                          2019-02-12 04:40:04.083000
# SourceComputerId             263a788b-6526-4cdc-8ed9-d79402fe4aa0
# Computer                                          MSTICAlertsWin1
# SubjectUserName                                  MSTICAlertsWin1$
# SubjectDomainName                                       WORKGROUP
# SubjectUserSid                                           S-1-5-18
# TargetUserName                                             SYSTEM
# TargetDomainName                                     NT AUTHORITY
# TargetUserSid                                            S-1-5-18
# TargetLogonId                                               0x3e7
# LogonProcessName                                         Advapi
# LogonType                                                       5
# AuthenticationPackageName                               Negotiate
# Status
# IpAddress                                                       -
# WorkstationName                                                 -
# TimeCreatedUtc                         2019-02-12 04:40:04.083000
# Name: 13, dtype: object

# %% [markdown]
# ## Selecting Columns

# %% [markdown]
# Selecting a single column

# %%
logons_df.Account
# Out:
# 13              NT AUTHORITY\SYSTEM
# 115             NT AUTHORITY\SYSTEM
# 124             MSTICAlertsWin1\ian
# 138      MSTICAlertsWin1\MSTICAdmin
# 153             MSTICAlertsWin1\ian
# 52              NT AUTHORITY\SYSTEM
# 44              NT AUTHORITY\SYSTEM
# 134             NT AUTHORITY\SYSTEM
# 10                NT AUTHORITY\IUSR
# 65              NT AUTHORITY\SYSTEM
# 51              NT AUTHORITY\SYSTEM
# 91              NT AUTHORITY\SYSTEM
# 14     NT AUTHORITY\NETWORK SERVICE
# 73             Window Manager\DWM-1
# 41              NT AUTHORITY\SYSTEM
# 77              NT AUTHORITY\SYSTEM
# 117             NT AUTHORITY\SYSTEM
# 105             NT AUTHORITY\SYSTEM
# 160             NT AUTHORITY\SYSTEM
# 69              NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %% [markdown]
# More general syntax and mandatory if column name has spaces or other illegal chars (like ".")

# %%
logons_df["Account"]
# Out:
# 13              NT AUTHORITY\SYSTEM
# 115             NT AUTHORITY\SYSTEM
# 124             MSTICAlertsWin1\ian
# 138      MSTICAlertsWin1\MSTICAdmin
# 153             MSTICAlertsWin1\ian
# 52              NT AUTHORITY\SYSTEM
# 44              NT AUTHORITY\SYSTEM
# 134             NT AUTHORITY\SYSTEM
# 10                NT AUTHORITY\IUSR
# 65              NT AUTHORITY\SYSTEM
# 51              NT AUTHORITY\SYSTEM
# 91              NT AUTHORITY\SYSTEM
# 14     NT AUTHORITY\NETWORK SERVICE
# 73             Window Manager\DWM-1
# 41              NT AUTHORITY\SYSTEM
# 77              NT AUTHORITY\SYSTEM
# 117             NT AUTHORITY\SYSTEM
# 105             NT AUTHORITY\SYSTEM
# 160             NT AUTHORITY\SYSTEM
# 69              NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %% [markdown]
# To select multiple columns you use a Python list

# %%
my_cols = ["Account", "TimeGenerated"]
logons_df[my_cols]
# Out:
#                           Account           TimeGenerated
# 13            NT AUTHORITY\SYSTEM 2019-02-12 04:40:04.083
# 115           NT AUTHORITY\SYSTEM 2019-02-12 21:43:25.113
# 124           MSTICAlertsWin1\ian 2019-02-12 20:41:17.310
# 138    MSTICAlertsWin1\MSTICAdmin 2019-02-12 20:19:41.937
# 153           MSTICAlertsWin1\ian 2019-02-15 03:56:32.210
# 52            NT AUTHORITY\SYSTEM 2019-02-09 12:35:51.683
# 44            NT AUTHORITY\SYSTEM 2019-02-10 20:03:56.173
# 134           NT AUTHORITY\SYSTEM 2019-02-12 22:14:07.417
# 10              NT AUTHORITY\IUSR 2019-02-12 04:40:12.360
# 65            NT AUTHORITY\SYSTEM 2019-02-14 04:31:12.283
# 51            NT AUTHORITY\SYSTEM 2019-02-09 12:32:50.220
# 91            NT AUTHORITY\SYSTEM 2019-02-13 21:35:26.413
# 14   NT AUTHORITY\NETWORK SERVICE 2019-02-12 04:40:04.207
# 73           Window Manager\DWM-1 2019-02-14 04:20:54.773
# 41            NT AUTHORITY\SYSTEM 2019-02-10 21:47:21.503
# 77            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.040
# 117           NT AUTHORITY\SYSTEM 2019-02-12 21:49:11.777
# 105           NT AUTHORITY\SYSTEM 2019-02-13 04:44:32.913
# 160           NT AUTHORITY\SYSTEM 2019-02-15 04:15:12.223
# 69            NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537

# %%
# Or just
logons_df[["Account", "TimeGenerated"]]
# Out:
#                           Account           TimeGenerated
# 13            NT AUTHORITY\SYSTEM 2019-02-12 04:40:04.083
# 115           NT AUTHORITY\SYSTEM 2019-02-12 21:43:25.113
# 124           MSTICAlertsWin1\ian 2019-02-12 20:41:17.310
# 138    MSTICAlertsWin1\MSTICAdmin 2019-02-12 20:19:41.937
# 153           MSTICAlertsWin1\ian 2019-02-15 03:56:32.210
# 52            NT AUTHORITY\SYSTEM 2019-02-09 12:35:51.683
# 44            NT AUTHORITY\SYSTEM 2019-02-10 20:03:56.173
# 134           NT AUTHORITY\SYSTEM 2019-02-12 22:14:07.417
# 10              NT AUTHORITY\IUSR 2019-02-12 04:40:12.360
# 65            NT AUTHORITY\SYSTEM 2019-02-14 04:31:12.283
# 51            NT AUTHORITY\SYSTEM 2019-02-09 12:32:50.220
# 91            NT AUTHORITY\SYSTEM 2019-02-13 21:35:26.413
# 14   NT AUTHORITY\NETWORK SERVICE 2019-02-12 04:40:04.207
# 73           Window Manager\DWM-1 2019-02-14 04:20:54.773
# 41            NT AUTHORITY\SYSTEM 2019-02-10 21:47:21.503
# 77            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.040
# 117           NT AUTHORITY\SYSTEM 2019-02-12 21:49:11.777
# 105           NT AUTHORITY\SYSTEM 2019-02-13 04:44:32.913
# 160           NT AUTHORITY\SYSTEM 2019-02-15 04:15:12.223
# 69            NT AUTHORITY\SYSTEM 2019-02-13 22:08:46.537

# %% [markdown]
# ### Use the columns property to get the column names

# %%
logons_df.columns
# Out:
# Index(['TenantId', 'Account', 'EventID', 'TimeGenerated', 'SourceComputerId',
#        'Computer', 'SubjectUserName', 'SubjectDomainName', 'SubjectUserSid',
#        'TargetUserName', 'TargetDomainName', 'TargetUserSid', 'TargetLogonId',
#        'LogonProcessName', 'LogonType', 'AuthenticationPackageName', 'Status',
#        'IpAddress', 'WorkstationName', 'TimeCreatedUtc'],
#       dtype='object')

# %%
logons_df[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [13, 115, 124, 138, 153, 52, 44, 134, 10, 65, 51, 91, 14, 73, 41, 77, 117, 105, 160, 69]

# %% [markdown]
# ## Indexes - brief introduction

# %%
logons_df.index
# Out:
# Int64Index([ 13, 115, 124, 138, 153,  52,  44, 134,  10,  65,  51,  91,  14,
#              73,  41,  77, 117, 105, 160,  69],
#            dtype='int64')

# %%
# Access a row at an index location
logons_df.loc[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 3
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/x0/m8g0zsf572dd2gg1g07hc7fw0000gn/T/ipykernel_8072/586825799.py in <module>
#       1 # Access a row at an index location
# ----> 2 logons_df.loc[3]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1162         # fall thru to straight lookup
#    1163         self._validate_key(key, axis)
# -> 1164         return self._get_label(key, axis=axis)
#    1165
#    1166     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#    1111     def _get_label(self, label, axis: int):
#    1112         # GH#5667 this will fail if the label is not present in the axis.
# -> 1113         return self.obj.xs(label, axis=axis)
#    1114
#    1115     def _handle_lowerdim_multi_index_axis0(self, tup: tuple):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3771                 raise TypeError(f"Expected label or tuple of labels, got {key}") from e
#    3772         else:
# -> 3773             loc = index.get_loc(key)
#    3774
#    3775             if isinstance(loc, np.ndarray):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 3

# %%
# Access a row at a physical row location
logons_df.iloc[3]
# Out:
# TenantId                             52b1ab41-869e-4138-9e40-2a4457f09bf0
# Account                                        MSTICAlertsWin1\MSTICAdmin
# EventID                                                              4624
# TimeGenerated                                  2019-02-12 04:38:16.550000
# SourceComputerId                     263a788b-6526-4cdc-8ed9-d79402fe4aa0
# Computer                                                  MSTICAlertsWin1
# SubjectUserName                                                         -
# SubjectDomainName                                                       -
# SubjectUserSid                                                    S-1-0-0
# TargetUserName                                                 MSTICAdmin
# TargetDomainName                                          MSTICAlertsWin1
# TargetUserSid                S-1-5-21-996632719-2361334927-4038480536-500
# TargetLogonId                                                   0xc912d62
# LogonProcessName                                                 NtLmSsp
# LogonType                                                               3
# AuthenticationPackageName                                            NTLM
# Status
# IpAddress                                                 131.107.147.209
# WorkstationName                                            IANHELLE-DEV17
# TimeCreatedUtc                                 2019-02-12 04:38:16.550000
# Name: 3, dtype: object

# %%
indexed_logons_df = logons_df.set_index("Account")
display(logons_df.head(3))
display(indexed_logons_df.head(3))
# Out:
#                                  TenantId              Account  EventID  \
# 13   52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 115  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 124  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\ian     4624
#
#               TimeGenerated                      SourceComputerId  \
# 13  2019-02-12 04:40:04.083  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 115 2019-02-12 21:43:25.113  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 124 2019-02-12 20:41:17.310  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 13   MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 115  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 124  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#     TargetUserName TargetDomainName  \
# 13          SYSTEM     NT AUTHORITY
# 115         SYSTEM     NT AUTHORITY
# 124            ian  MSTICAlertsWin1
#
#                                      TargetUserSid TargetLogonId  \
# 13                                        S-1-5-18         0x3e7
# 115                                       S-1-5-18         0x3e7
# 124  S-1-5-21-996632719-2361334927-4038480536-1120      0x7ad58d
#
#     LogonProcessName  LogonType AuthenticationPackageName Status IpAddress  \
# 13          Advapi            5                 Negotiate                -
# 115         Advapi            5                 Negotiate                -
# 124         Advapi            4                 Negotiate                -
#
#      WorkstationName          TimeCreatedUtc
# 13                 - 2019-02-12 04:40:04.083
# 115                - 2019-02-12 21:43:25.113
# 124  MSTICAlertsWin1 2019-02-12 20:41:17.310
#                                                  TenantId  EventID  \
# Account
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
# MSTICAlertsWin1\ian  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
#
#                               TimeGenerated  \
# Account
# NT AUTHORITY\SYSTEM 2019-02-12 04:40:04.083
# NT AUTHORITY\SYSTEM 2019-02-12 21:43:25.113
# MSTICAlertsWin1\ian 2019-02-12 20:41:17.310
#
#                                          SourceComputerId         Computer  \
# Account
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
# MSTICAlertsWin1\ian  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
#
#                       SubjectUserName SubjectDomainName SubjectUserSid  \
# Account
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# MSTICAlertsWin1\ian  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#                     TargetUserName TargetDomainName  \
# Account
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY
# MSTICAlertsWin1\ian            ian  MSTICAlertsWin1
#
#                                                      TargetUserSid  \
# Account
# NT AUTHORITY\SYSTEM                                       S-1-5-18
# NT AUTHORITY\SYSTEM                                       S-1-5-18
# MSTICAlertsWin1\ian  S-1-5-21-996632719-2361334927-4038480536-1120
#
#                     TargetLogonId LogonProcessName  LogonType  \
# Account
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
# MSTICAlertsWin1\ian      0x7ad58d         Advapi            4
#
#                     AuthenticationPackageName Status IpAddress  \
# Account
# NT AUTHORITY\SYSTEM                 Negotiate                -
# NT AUTHORITY\SYSTEM                 Negotiate                -
# MSTICAlertsWin1\ian                 Negotiate                -
#
#                      WorkstationName          TimeCreatedUtc
# Account
# NT AUTHORITY\SYSTEM                - 2019-02-12 04:40:04.083
# NT AUTHORITY\SYSTEM                - 2019-02-12 21:43:25.113
# MSTICAlertsWin1\ian  MSTICAlertsWin1 2019-02-12 20:41:17.310

# %%
indexed_logons_df.loc["NT AUTHORITY\\SYSTEM"].head()
# Out:
#                                                  TenantId  EventID  \
# Account
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
# NT AUTHORITY\SYSTEM  52b1ab41-869e-4138-9e40-2a4457f09bf0     4624
#
#                               TimeGenerated  \
# Account
# NT AUTHORITY\SYSTEM 2019-02-12 04:40:04.083
# NT AUTHORITY\SYSTEM 2019-02-12 21:43:25.113
# NT AUTHORITY\SYSTEM 2019-02-09 12:35:51.683
# NT AUTHORITY\SYSTEM 2019-02-10 20:03:56.173
# NT AUTHORITY\SYSTEM 2019-02-12 22:14:07.417
#
#                                          SourceComputerId         Computer  \
# Account
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
# NT AUTHORITY\SYSTEM  263a788b-6526-4cdc-8ed9-d79402fe4aa0  MSTICAlertsWin1
#
#                       SubjectUserName SubjectDomainName SubjectUserSid  \
# Account
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# NT AUTHORITY\SYSTEM  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#                     TargetUserName TargetDomainName TargetUserSid  \
# Account
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
# NT AUTHORITY\SYSTEM         SYSTEM     NT AUTHORITY      S-1-5-18
#
#                     TargetLogonId LogonProcessName  LogonType  \
# Account
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
# NT AUTHORITY\SYSTEM         0x3e7         Advapi            5
#
#                     AuthenticationPackageName Status IpAddress  \
# Account
# NT AUTHORITY\SYSTEM                 Negotiate                -
# NT AUTHORITY\SYSTEM                 Negotiate                -
# NT AUTHORITY\SYSTEM                 Negotiate                -
# NT AUTHORITY\SYSTEM                 Negotiate                -
# NT AUTHORITY\SYSTEM                 Negotiate                -
#
#                     WorkstationName          TimeCreatedUtc
# Account
# NT AUTHORITY\SYSTEM               - 2019-02-12 04:40:04.083
# NT AUTHORITY\SYSTEM               - 2019-02-12 21:43:25.113
# NT AUTHORITY\SYSTEM               - 2019-02-09 12:35:51.683
# NT AUTHORITY\SYSTEM               - 2019-02-10 20:03:56.173
# NT AUTHORITY\SYSTEM               - 2019-02-12 22:14:07.417

# %%
# Physical row indexing works as before
indexed_logons_df.iloc[3]
# Out:
# TenantId                             52b1ab41-869e-4138-9e40-2a4457f09bf0
# EventID                                                              4624
# TimeGenerated                                  2019-02-12 20:19:41.937000
# SourceComputerId                     263a788b-6526-4cdc-8ed9-d79402fe4aa0
# Computer                                                  MSTICAlertsWin1
# SubjectUserName                                                         -
# SubjectDomainName                                                       -
# SubjectUserSid                                                    S-1-0-0
# TargetUserName                                                 MSTICAdmin
# TargetDomainName                                          MSTICAlertsWin1
# TargetUserSid                S-1-5-21-996632719-2361334927-4038480536-500
# TargetLogonId                                                    0x2da7cd
# LogonProcessName                                                 NtLmSsp
# LogonType                                                               3
# AuthenticationPackageName                                            NTLM
# Status
# IpAddress                                                 131.107.147.209
# WorkstationName                                            IANHELLE-DEV17
# TimeCreatedUtc                                 2019-02-12 20:19:41.937000
# Name: MSTICAlertsWin1\MSTICAdmin, dtype: object

# %% [markdown]
# ## Accessing individual values

# %%
print("iloc + named column", logons_df.iloc[0].Account)
print("at - row idx + named column", logons_df.at[0, "Account"])
print("iat - row idx + column idx", logons_df.iat[0, 1])


print("\nBut if the index is not unique 'at' returns a series\n")

print(
    "at - row idx + named column",
    "Type:",
    type(indexed_logons_df.at["NT AUTHORITY\\SYSTEM", "EventID"]),
    "Result:",
    indexed_logons_df.at["NT AUTHORITY\\SYSTEM", "EventID"],
    sep="\n",
)
# Out:
# iloc + named column NT AUTHORITY\SYSTEM
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/x0/m8g0zsf572dd2gg1g07hc7fw0000gn/T/ipykernel_8072/3575590756.py in <module>
#       1 print("iloc + named column", logons_df.iloc[0].Account)
# ----> 2 print("at - row idx + named column", logons_df.at[0, "Account"])
#       3 print("iat - row idx + column idx", logons_df.iat[0, 1])
#       4
#       5
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2273             return self.obj.loc[key]
#    2274
# -> 2275         return super().__getitem__(key)
#    2276
#    2277     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    2220
#    2221         key = self._convert_key(key)
# -> 2222         return self.obj._get_value(*key, takeable=self._takeable)
#    2223
#    2224     def __setitem__(self, key, value):
#
# /usr/local/lib/python3.9/site-packages/pandas/core/frame.py in _get_value(self, index, col, takeable)
#    3574
#    3575         try:
# -> 3576             loc = engine.get_loc(index)
#    3577             return series._values[loc]
#    3578         except AttributeError:
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0

# %% [markdown]
# # Selecting/Searching

# %% [markdown]
# ## Specific row by number

# %%
logons_df.iloc[2].Account
# Out:
# 'MSTICAlertsWin1\\ian'

# %%
logons_df.iloc[3:6]
# Out:
#                                  TenantId                     Account  \
# 138  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
# 153  52b1ab41-869e-4138-9e40-2a4457f09bf0         MSTICAlertsWin1\ian
# 52   52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
#
#      EventID           TimeGenerated                      SourceComputerId  \
# 138     4624 2019-02-12 20:19:41.937  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 153     4624 2019-02-15 03:56:32.210  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 52      4624 2019-02-09 12:35:51.683  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 138  MSTICAlertsWin1                 -                 -        S-1-0-0
# 153  MSTICAlertsWin1                 -                 -        S-1-0-0
# 52   MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#     TargetUserName TargetDomainName  \
# 138     MSTICAdmin  MSTICAlertsWin1
# 153            ian  MSTICAlertsWin1
# 52          SYSTEM     NT AUTHORITY
#
#                                      TargetUserSid TargetLogonId  \
# 138   S-1-5-21-996632719-2361334927-4038480536-500      0x2da7cd
# 153  S-1-5-21-996632719-2361334927-4038480536-1120     0x10957b1
# 52                                        S-1-5-18         0x3e7
#
#     LogonProcessName  LogonType AuthenticationPackageName Status  \
# 138         NtLmSsp           3                      NTLM
# 153         NtLmSsp           3                      NTLM
# 52          Advapi            5                 Negotiate
#
#            IpAddress WorkstationName          TimeCreatedUtc
# 138  131.107.147.209  IANHELLE-DEV17 2019-02-12 20:19:41.937
# 153  131.107.147.209  IANHELLE-DEV17 2019-02-15 03:56:32.210
# 52                 -               - 2019-02-09 12:35:51.683

# %%
logons_df.head(5) == logons_df.iloc[0:5]
# Out:
#      TenantId  Account  EventID  TimeGenerated  SourceComputerId  Computer  \
# 13       True     True     True           True              True      True
# 115      True     True     True           True              True      True
# 124      True     True     True           True              True      True
# 138      True     True     True           True              True      True
# 153      True     True     True           True              True      True
#
#      SubjectUserName  SubjectDomainName  SubjectUserSid  TargetUserName  \
# 13              True               True            True            True
# 115             True               True            True            True
# 124             True               True            True            True
# 138             True               True            True            True
# 153             True               True            True            True
#
#      TargetDomainName  TargetUserSid  TargetLogonId  LogonProcessName  \
# 13               True           True           True              True
# 115              True           True           True              True
# 124              True           True           True              True
# 138              True           True           True              True
# 153              True           True           True              True
#
#      LogonType  AuthenticationPackageName  Status  IpAddress  WorkstationName  \
# 13        True                       True    True       True             True
# 115       True                       True    True       True             True
# 124       True                       True    True       True             True
# 138       True                       True    True       True             True
# 153       True                       True    True       True             True
#
#      TimeCreatedUtc
# 13             True
# 115            True
# 124            True
# 138            True
# 153            True

# %% [markdown]
# ## Select by content - Boolean expression
#
# - ==
# - !=
# - \>, <, >=, <=

# %%
logons_df["Account"] == "MSTICAlertsWin1\\MSTICAdmin"
# Out:
# 13     False
# 115    False
# 124    False
# 138     True
# 153    False
# 52     False
# 44     False
# 134    False
# 10     False
# 65     False
# 51     False
# 91     False
# 14     False
# 73     False
# 41     False
# 77     False
# 117    False
# 105    False
# 160    False
# 69     False
# Name: Account, dtype: bool

# %% [markdown]
# ### Use boolean result of expression to filter DataFrame

# %%
logons_df.loc[logons_df["Account"] == "MSTICAlertsWin1\\MSTICAdmin"]
# Out:
#                                  TenantId                     Account  \
# 138  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
#
#      EventID           TimeGenerated                      SourceComputerId  \
# 138     4624 2019-02-12 20:19:41.937  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#             Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 138  MSTICAlertsWin1               -                 -        S-1-0-0
#
#     TargetUserName TargetDomainName  \
# 138     MSTICAdmin  MSTICAlertsWin1
#
#                                     TargetUserSid TargetLogonId  \
# 138  S-1-5-21-996632719-2361334927-4038480536-500      0x2da7cd
#
#     LogonProcessName  LogonType AuthenticationPackageName Status  \
# 138         NtLmSsp           3                      NTLM
#
#            IpAddress WorkstationName          TimeCreatedUtc
# 138  131.107.147.209  IANHELLE-DEV17 2019-02-12 20:19:41.937

# %% [markdown]
# ## Other operators with boolean indexing
#
# Operators vary depending on data type!!!

# %%
logons_df.dtypes
# Out:
# TenantId                             object
# Account                              object
# EventID                               int64
# TimeGenerated                datetime64[ns]
# SourceComputerId                     object
# Computer                             object
# SubjectUserName                      object
# SubjectDomainName                    object
# SubjectUserSid                       object
# TargetUserName                       object
# TargetDomainName                     object
# TargetUserSid                        object
# TargetLogonId                        object
# LogonProcessName                     object
# LogonType                             int64
# AuthenticationPackageName            object
# Status                               object
# IpAddress                            object
# WorkstationName                      object
# TimeCreatedUtc               datetime64[ns]
# dtype: object

# %%
logons_df[logons_df["Account"].endswith("MSTICAdmin")]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/x0/m8g0zsf572dd2gg1g07hc7fw0000gn/T/ipykernel_8072/3533411303.py in <module>
# ----> 1 logons_df[logons_df["Account"].endswith("MSTICAdmin")]
#
# /usr/local/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5476         ):
#    5477             return self[name]
# -> 5478         return object.__getattribute__(self, name)
#    5479
#    5480     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'endswith'

# %%
logons_df["Account"]
# Out:
# 13              NT AUTHORITY\SYSTEM
# 115             NT AUTHORITY\SYSTEM
# 124             MSTICAlertsWin1\ian
# 138      MSTICAlertsWin1\MSTICAdmin
# 153             MSTICAlertsWin1\ian
# 52              NT AUTHORITY\SYSTEM
# 44              NT AUTHORITY\SYSTEM
# 134             NT AUTHORITY\SYSTEM
# 10                NT AUTHORITY\IUSR
# 65              NT AUTHORITY\SYSTEM
# 51              NT AUTHORITY\SYSTEM
# 91              NT AUTHORITY\SYSTEM
# 14     NT AUTHORITY\NETWORK SERVICE
# 73             Window Manager\DWM-1
# 41              NT AUTHORITY\SYSTEM
# 77              NT AUTHORITY\SYSTEM
# 117             NT AUTHORITY\SYSTEM
# 105             NT AUTHORITY\SYSTEM
# 160             NT AUTHORITY\SYSTEM
# 69              NT AUTHORITY\SYSTEM
# Name: Account, dtype: object

# %% [markdown]
# ### We need to tell pandas to treat the series as a string
# (a bit like tostring(dynamic) in KQL)
#
# logons_df[logons_df["Account"].**str**.contains("MSTICAdmin")]

# %%
logons_df[logons_df["Account"].str.endswith("MSTICAdmin")]
# Out:
#                                TenantId                     Account  EventID  \
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 3  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 4  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 3 2019-02-12 04:38:16.550  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 4 2019-02-12 04:38:21.370  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 1  MSTICAlertsWin1               -                 -        S-1-0-0
# 2  MSTICAlertsWin1               -                 -        S-1-0-0
# 3  MSTICAlertsWin1               -                 -        S-1-0-0
# 4  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
# 3     MSTICAdmin  MSTICAlertsWin1
# 4     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
# 3  S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 4  S-1-5-21-996632719-2361334927-4038480536-500     0xc913737
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 1         NtLmSsp           3                      NTLM
# 2         NtLmSsp           3                      NTLM
# 3         NtLmSsp           3                      NTLM
# 4         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997
# 3  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:38:16.550
# 4  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:38:21.370

# %% [markdown]
# ## Multiple conditions
# ```
# & == AND
# | == OR
# ~ == NOT
# ```
#
# *Always use parentheses around individual expressions in composite logical expressions!*

# %%
logons_df[
    logons_df["Account"].str.contains("MSTICAdmin")
]

# %%
t1 = pd.Timestamp("2019-02-12 04:37:25")
t2 = pd.to_datetime("2019-02-12 04:37:26")
t1, t2
# Out:
# (Timestamp('2019-02-12 04:37:25'), Timestamp('2019-02-12 04:37:26'))

# %%
logons_df[
    (logons_df["Account"].str.contains("MSTICAdmin"))
    &
    (logons_df["TimeGenerated"] >= t1)
    &
    (logons_df["TimeGenerated"] <= t2)
]
# Out:
#                                TenantId                     Account  EventID  \
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 1  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 1     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 1         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340

# %%
logons_df[
    ~(logons_df["Account"].str.contains("MSTICAdmin"))
    &
    (logons_df["TimeGenerated"] >= t2)
].head(5)
# Out:
#                                TenantId              Account  EventID  \
# 0  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 5  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 6  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 7  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 8  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
#
#             TimeGenerated                      SourceComputerId  \
# 0 2019-02-12 04:56:34.307  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 5 2019-02-12 04:50:09.713  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 6 2019-02-12 04:50:18.660  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 7 2019-02-12 04:43:56.327  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 8 2019-02-12 04:44:10.343  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 0  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 5  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 6  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 7  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 8  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#   TargetUserName TargetDomainName TargetUserSid TargetLogonId  \
# 0         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 5         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 6         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 7         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 8         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
#
#   LogonProcessName  LogonType AuthenticationPackageName Status IpAddress  \
# 0         Advapi            5                 Negotiate                -
# 5         Advapi            5                 Negotiate                -
# 6         Advapi            5                 Negotiate                -
# 7         Advapi            5                 Negotiate                -
# 8         Advapi            5                 Negotiate                -
#
#   WorkstationName          TimeCreatedUtc
# 0               - 2019-02-12 04:56:34.307
# 5               - 2019-02-12 04:50:09.713
# 6               - 2019-02-12 04:50:18.660
# 7               - 2019-02-12 04:43:56.327
# 8               - 2019-02-12 04:44:10.343

# %%
logons_df[
    (logons_df["LogonType"] == 3)
    &
    (logons_df["TimeGenerated"].dt.hour == 4)
    &
    (logons_df["TimeGenerated"].dt.minute == 37)
]
# Out:
#                                TenantId                     Account  EventID  \
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 1  MSTICAlertsWin1               -                 -        S-1-0-0
# 2  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 1         NtLmSsp           3                      NTLM
# 2         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997

# %% [markdown]
# ### Boolean indexes are Pandas series - you can save and re-use

# %%
logon_type_3 = logons_df["LogonType"] == 3
hour_4 = logons_df["TimeGenerated"].dt.hour == 4
minute_37 = logons_df["TimeGenerated"].dt.minute == 37

logons_df[logon_type_3 & hour_4 & minute_37]
# Out:
#                                TenantId                     Account  EventID  \
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 1  MSTICAlertsWin1               -                 -        S-1-0-0
# 2  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 1         NtLmSsp           3                      NTLM
# 2         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997

# %% [markdown]
# ### Pandas `str` and `dt` (datetime) accessor functions

# %%
str_funcs = [func for func in dir(logons_df["Account"].str) if not func.startswith("_")]
print("Pandas 'str' functions")
print("----------------------")
print(", ".join(str_funcs))
print("\nRead more here")
print("https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary")
dt_funcs = [func for func in dir(logons_df["TimeGenerated"].dt) if not func.startswith("_")]
print("\nPandas 'dt' (datetime) functions")
print("----------------------------------")
print(", ".join(dt_funcs))
# Out:
# Pandas 'str' functions
# ----------------------
# capitalize, casefold, cat, center, contains, count, decode, encode, endswith, extract, extractall, find, findall, fullmatch, get, get_dummies, index, isalnum, isalpha, isdecimal, isdigit, islower, isnumeric, isspace, istitle, isupper, join, len, ljust, lower, lstrip, match, normalize, pad, partition, repeat, replace, rfind, rindex, rjust, rpartition, rsplit, rstrip, slice, slice_replace, split, startswith, strip, swapcase, title, translate, upper, wrap, zfill
#
# Read more here
# https://pandas.pydata.org/pandas-docs/stable/user_guide/text.html#method-summary
#
# Pandas 'dt' (datetime) functions
# ----------------------------------
# ceil, date, day, day_name, day_of_week, day_of_year, dayofweek, dayofyear, days_in_month, daysinmonth, floor, freq, hour, is_leap_year, is_month_end, is_month_start, is_quarter_end, is_quarter_start, is_year_end, is_year_start, isocalendar, microsecond, minute, month, month_name, nanosecond, normalize, quarter, round, second, strftime, time, timetz, to_period, to_pydatetime, tz, tz_convert, tz_localize, week, weekday, weekofyear, year

# %% [markdown]
# ## `isin` operator/function

# %%
logons_df[logons_df["TargetUserName"].isin(["MSTICAdmin", "SYSTEM"])]

# %% [markdown]
# ## query function
# Useful for simpler queries - and definitely nicer-looking but some limitations - only simple operators supported.
#
# Good for quick things but I prefer the boolean stuff for more complex queries.
#
# To reference Python variables prefix the variable name with "@" (see second example)

# %%
logons_df.query("TargetUserName == 'MSTICAdmin' and TargetLogonId == '0xc90ea44'")

logons_df.query("TargetUserName == 'MSTICAdmin' and TargetLogonId == '0xc90ea44' and TimeGenerated > @t2")
# Out:
#                                TenantId                     Account  EventID  \
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 2  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 2     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 2         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997

# %%
(
    logons_df
    .query("TargetLogonId == '0xc90ea44' and TimeGenerated > @t2")
    [logons_df["Account"].str.match("MST.*")]
)
# Out:
# C:\Users\Ian\Anaconda3\envs\condadev\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
#                                TenantId                     Account  EventID  \
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer SubjectUserName SubjectDomainName SubjectUserSid  \
# 2  MSTICAlertsWin1               -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 2     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 2         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997

# %% [markdown]
# ## Combing Column Select and Query

# %%
(
    logons_df[logons_df["Account"].str.contains("MSTICAdmin")]
    [["Account", "TimeGenerated"]]
)
# Out:
#                       Account           TimeGenerated
# 1  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:37:25.340
# 2  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:37:27.997
# 3  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:38:16.550
# 4  MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:38:21.370

# %% [markdown]
# ### and with column rename

# %%
(
    logons_df[logons_df["Account"].str.contains("MSTICAdmin")]
    [["Account", "TimeGenerated"]]
    .rename(columns={"Account": "User", "TimeGenerated": "Time"})
)

# %% [markdown]
# # Sorting and removing duplicates

# %%
logons_df.sort_values("TimeGenerated", ascending=False).head(3)
# Out:
#                                TenantId              Account  EventID  \
# 0  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 6  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 5  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
#
#             TimeGenerated                      SourceComputerId  \
# 0 2019-02-12 04:56:34.307  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 6 2019-02-12 04:50:18.660  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 5 2019-02-12 04:50:09.713  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 0  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 6  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 5  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#   TargetUserName TargetDomainName TargetUserSid TargetLogonId  \
# 0         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 6         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 5         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
#
#   LogonProcessName  LogonType AuthenticationPackageName Status IpAddress  \
# 0         Advapi            5                 Negotiate                -
# 6         Advapi            5                 Negotiate                -
# 5         Advapi            5                 Negotiate                -
#
#   WorkstationName          TimeCreatedUtc
# 0               - 2019-02-12 04:56:34.307
# 6               - 2019-02-12 04:50:18.660
# 5               - 2019-02-12 04:50:09.713

# %%
(
    logons_df[["Account", "LogonType"]]
    .drop_duplicates()
    .sort_values("Account")
)
# Out:
#                          Account  LogonType
# 1     MSTICAlertsWin1\MSTICAdmin          3
# 10             NT AUTHORITY\IUSR          5
# 17    NT AUTHORITY\LOCAL SERVICE          5
# 14  NT AUTHORITY\NETWORK SERVICE          5
# 0            NT AUTHORITY\SYSTEM          5
# 12           NT AUTHORITY\SYSTEM          0
# 15          Window Manager\DWM-1          2

# %% [markdown]
# # Grouping and Aggregation
# <p style="color: white; background-color: green; text-align: center">New</p>

# %%
logons_df.groupby("Account")

# %% [markdown]
# ### You need an aggregator (or iterator) make use of grouping

# %%
logons_df.groupby("Account").count() # Yuk!
# Out:
#                               TenantId  EventID  TimeGenerated  \
# Account
# MSTICAlertsWin1\MSTICAdmin           4        4              4
# NT AUTHORITY\IUSR                    1        1              1
# NT AUTHORITY\LOCAL SERVICE           1        1              1
# NT AUTHORITY\NETWORK SERVICE         1        1              1
# NT AUTHORITY\SYSTEM                 11       11             11
# Window Manager\DWM-1                 2        2              2
#
#                               SourceComputerId  Computer  SubjectUserName  \
# Account
# MSTICAlertsWin1\MSTICAdmin                   4         4                4
# NT AUTHORITY\IUSR                            1         1                1
# NT AUTHORITY\LOCAL SERVICE                   1         1                1
# NT AUTHORITY\NETWORK SERVICE                 1         1                1
# NT AUTHORITY\SYSTEM                         11        11               11
# Window Manager\DWM-1                         2         2                2
#
#                               SubjectDomainName  SubjectUserSid  \
# Account
# MSTICAlertsWin1\MSTICAdmin                    4               4
# NT AUTHORITY\IUSR                             1               1
# NT AUTHORITY\LOCAL SERVICE                    1               1
# NT AUTHORITY\NETWORK SERVICE                  1               1
# NT AUTHORITY\SYSTEM                          11              11
# Window Manager\DWM-1                          2               2
#
#                               TargetUserName  TargetDomainName  TargetUserSid  \
# Account
# MSTICAlertsWin1\MSTICAdmin                 4                 4              4
# NT AUTHORITY\IUSR                          1                 1              1
# NT AUTHORITY\LOCAL SERVICE                 1                 1              1
# NT AUTHORITY\NETWORK SERVICE               1                 1              1
# NT AUTHORITY\SYSTEM                       11                11             11
# Window Manager\DWM-1                       2                 2              2
#
#                               TargetLogonId  LogonProcessName  LogonType  \
# Account
# MSTICAlertsWin1\MSTICAdmin                4                 4          4
# NT AUTHORITY\IUSR                         1                 1          1
# NT AUTHORITY\LOCAL SERVICE                1                 1          1
# NT AUTHORITY\NETWORK SERVICE              1                 1          1
# NT AUTHORITY\SYSTEM                      11                11         11
# Window Manager\DWM-1                      2                 2          2
#
#                               AuthenticationPackageName  Status  IpAddress  \
# Account
# MSTICAlertsWin1\MSTICAdmin                            4       4          4
# NT AUTHORITY\IUSR                                     1       1          1
# NT AUTHORITY\LOCAL SERVICE                            1       1          1
# NT AUTHORITY\NETWORK SERVICE                          1       1          1
# NT AUTHORITY\SYSTEM                                  11      11         11
# Window Manager\DWM-1                                  2       2          2
#
#                               WorkstationName  TimeCreatedUtc
# Account
# MSTICAlertsWin1\MSTICAdmin                  4               4
# NT AUTHORITY\IUSR                           1               1
# NT AUTHORITY\LOCAL SERVICE                  1               1
# NT AUTHORITY\NETWORK SERVICE                1               1
# NT AUTHORITY\SYSTEM                        11              11
# Window Manager\DWM-1                        2               2

# %%
(
    logons_df[["TimeGenerated", "Account"]]
    .groupby("Account")
    .count()
    .rename(columns={"TimeGenerated": "Count"})
)
# Out:
#                               Count
# Account
# MSTICAlertsWin1\MSTICAdmin        4
# NT AUTHORITY\IUSR                 1
# NT AUTHORITY\LOCAL SERVICE        1
# NT AUTHORITY\NETWORK SERVICE      1
# NT AUTHORITY\SYSTEM              11
# Window Manager\DWM-1              2

# %%
for name, logon_group in logons_df.groupby("Account"):
    print(name, type(logon_group), "size", logon_group.shape)

print("\nCollect in dictionary")
df_dict = {name: df for name, df in logons_df.groupby("Account")}

[print(f"{name}: df") for name in df_dict]
# Out:
# MSTICAlertsWin1\MSTICAdmin <class 'pandas.core.frame.DataFrame'> size (4, 20)
# NT AUTHORITY\IUSR <class 'pandas.core.frame.DataFrame'> size (1, 20)
# NT AUTHORITY\LOCAL SERVICE <class 'pandas.core.frame.DataFrame'> size (1, 20)
# NT AUTHORITY\NETWORK SERVICE <class 'pandas.core.frame.DataFrame'> size (1, 20)
# NT AUTHORITY\SYSTEM <class 'pandas.core.frame.DataFrame'> size (11, 20)
# Window Manager\DWM-1 <class 'pandas.core.frame.DataFrame'> size (2, 20)
#
# Collect in dictionary
# MSTICAlertsWin1\MSTICAdmin: df
# NT AUTHORITY\IUSR: df
# NT AUTHORITY\LOCAL SERVICE: df
# NT AUTHORITY\NETWORK SERVICE: df
# NT AUTHORITY\SYSTEM: df
# Window Manager\DWM-1: df
# [None, None, None, None, None, None]

# %% [markdown]
# ## Grouping with Multiple aggregation functions

# %%
(
    logons_df[["TimeGenerated", "EventID", "Account"]]
    .groupby("Account")
    .agg({"TimeGenerated": "max", "EventID": "sum"})
    .rename(columns={"TimeGenerated": "LastTime"})
)
# Out:
#                                             LastTime  EventID
# Account
# MSTICAlertsWin1\MSTICAdmin   2019-02-15 03:57:02.593    83232
# MSTICAlertsWin1\ian          2019-02-15 03:56:34.440    36992
# NT AUTHORITY\IUSR            2019-02-14 04:20:56.110     9248
# NT AUTHORITY\LOCAL SERVICE   2019-02-14 04:20:54.803     9248
# NT AUTHORITY\NETWORK SERVICE 2019-02-14 04:20:54.630     9248
# NT AUTHORITY\SYSTEM          2019-02-15 11:51:37.597   564128
# Window Manager\DWM-1         2019-02-14 04:20:54.773    18496
# Window Manager\DWM-2         2019-02-15 03:57:01.903    27744

# %% [markdown]
# ## Grouping with multiple columns

# %%
(
    logons_full_df[["TimeGenerated", "EventID", "Account", "LogonType"]]      # DF input fields
    .groupby(["Account", "LogonType"])                                        # Grouping fields
    .agg({"TimeGenerated": "max", "EventID": "count"})                        # aggregate operations
    .rename(columns={"TimeGenerated": "LastTime", "EventID": "Count"})        # Rename output
)
# Out:
#                                                       LastTime  Count
# Account                      LogonType
# MSTICAlertsWin1\MSTICAdmin   3         2019-02-15 03:57:00.207      8
#                              4         2019-02-14 11:51:37.603      8
#                              10        2019-02-15 03:57:02.593      2
# MSTICAlertsWin1\ian          2         2019-02-12 20:29:51.030      2
#                              3         2019-02-15 03:56:34.440      5
#                              4         2019-02-12 20:41:17.310      1
# NT AUTHORITY\IUSR            5         2019-02-14 04:20:56.110      2
# NT AUTHORITY\LOCAL SERVICE   5         2019-02-14 04:20:54.803      2
# NT AUTHORITY\NETWORK SERVICE 5         2019-02-14 04:20:54.630      2
# NT AUTHORITY\SYSTEM          0         2019-02-14 04:20:54.370      2
#                              5         2019-02-15 11:51:37.597    120
# Window Manager\DWM-1         2         2019-02-14 04:20:54.773      4
# Window Manager\DWM-2         2         2019-02-15 03:57:01.903      6

# %% [markdown]
# ## Using pd.Grouper to group by time interval

# %%
(
    logons_full_df[["TimeGenerated", "EventID", "Account", "LogonType"]]
    .groupby(["Account", pd.Grouper(key="TimeGenerated", freq="1D")])
    .agg({"TimeGenerated": "max", "EventID": "count"})
    .rename(columns={"TimeGenerated": "LastTime", "EventID": "Count"})
)
# Out:
#                                                           LastTime  Count
# Account                      TimeGenerated
# MSTICAlertsWin1\MSTICAdmin   2019-02-09    2019-02-09 23:26:47.700      1
#                              2019-02-11    2019-02-11 22:47:53.750      4
#                              2019-02-12    2019-02-12 20:19:44.767      7
#                              2019-02-13    2019-02-13 23:07:23.823      2
#                              2019-02-14    2019-02-14 11:51:37.603      1
#                              2019-02-15    2019-02-15 03:57:02.593      3
# MSTICAlertsWin1\ian          2019-02-12    2019-02-12 20:41:17.310      3
#                              2019-02-13    2019-02-13 00:57:37.187      3
#                              2019-02-15    2019-02-15 03:56:34.440      2
# NT AUTHORITY\IUSR            2019-02-12    2019-02-12 04:40:12.360      1
#                              2019-02-14    2019-02-14 04:20:56.110      1
# NT AUTHORITY\LOCAL SERVICE   2019-02-12    2019-02-12 04:40:04.573      1
#                              2019-02-14    2019-02-14 04:20:54.803      1
# NT AUTHORITY\NETWORK SERVICE 2019-02-12    2019-02-12 04:40:04.207      1
#                              2019-02-14    2019-02-14 04:20:54.630      1
# NT AUTHORITY\SYSTEM          2019-02-09    2019-02-09 12:35:51.683      2
#                              2019-02-10    2019-02-10 21:47:21.503     11
#                              2019-02-11    2019-02-11 09:59:02.593      2
#                              2019-02-12    2019-02-12 22:20:59.200     53
#                              2019-02-13    2019-02-13 22:08:46.537     10
#                              2019-02-14    2019-02-14 14:51:37.637     33
#                              2019-02-15    2019-02-15 11:51:37.597     11
# Window Manager\DWM-1         2019-02-12    2019-02-12 04:40:04.483      2
#                              2019-02-14    2019-02-14 04:20:54.773      2
# Window Manager\DWM-2         2019-02-12    2019-02-12 22:22:21.240      4
#                              2019-02-15    2019-02-15 03:57:01.903      2

# %% [markdown]
# # Adding and removing columns

# %%
new_df = logons_df.copy()

# Adding a static value
new_df["StaticValue"] = "A logon"
# Extracting a substring (there are several ways to do this)
new_df["NTDomain"] = new_df.Account.str.split("\\", 1, expand=True)[0]
# Transforming using an accessor
new_df["DayOfWeek"] = new_df.TimeGenerated.dt.day_name()
# Arithmetic calculations
new_df["BigEventID"] = new_df.EventID * 1000000
new_df["SameTimeTomorrow"] = new_df.TimeGenerated + pd.Timedelta("1D")

new_df[[
    "Account", "TimeGenerated", "StaticValue", "NTDomain", "DayOfWeek", "BigEventID", "SameTimeTomorrow"
]].head()
# Out:
#                         Account           TimeGenerated StaticValue  \
# 99         Window Manager\DWM-2 2019-02-12 22:22:21.240     A logon
# 89          NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.763     A logon
# 32          NT AUTHORITY\SYSTEM 2019-02-12 06:42:08.110     A logon
# 3    MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:38:16.550     A logon
# 123         NT AUTHORITY\SYSTEM 2019-02-12 20:39:14.110     A logon
#
#             NTDomain DayOfWeek  BigEventID        SameTimeTomorrow
# 99    Window Manager   Tuesday  4624000000 2019-02-13 22:22:21.240
# 89      NT AUTHORITY  Thursday  4624000000 2019-02-15 04:20:55.763
# 32      NT AUTHORITY   Tuesday  4624000000 2019-02-13 06:42:08.110
# 3    MSTICAlertsWin1   Tuesday  4624000000 2019-02-13 04:38:16.550
# 123     NT AUTHORITY   Tuesday  4624000000 2019-02-13 20:39:14.110

# %%
new_df[["Account", "TimeGenerated", "StaticValue", "NTDomain", "DayOfWeek"]].drop(columns=["NTDomain"])
# Out:
#                           Account           TimeGenerated StaticValue  \
# 99           Window Manager\DWM-2 2019-02-12 22:22:21.240     A logon
# 89            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.763     A logon
# 32            NT AUTHORITY\SYSTEM 2019-02-12 06:42:08.110     A logon
# 3      MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:38:16.550     A logon
# 123           NT AUTHORITY\SYSTEM 2019-02-12 20:39:14.110     A logon
# 47            NT AUTHORITY\SYSTEM 2019-02-10 00:48:31.607     A logon
# 45            NT AUTHORITY\SYSTEM 2019-02-10 20:03:57.417     A logon
# 1      MSTICAlertsWin1\MSTICAdmin 2019-02-12 04:37:25.340     A logon
# 81            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.503     A logon
# 158          Window Manager\DWM-2 2019-02-15 03:57:01.903     A logon
# 106           NT AUTHORITY\SYSTEM 2019-02-13 03:15:18.813     A logon
# 0             NT AUTHORITY\SYSTEM 2019-02-12 04:56:34.307     A logon
# 46            NT AUTHORITY\SYSTEM 2019-02-10 05:10:54.300     A logon
# 27            NT AUTHORITY\SYSTEM 2019-02-12 04:40:11.567     A logon
# 72   NT AUTHORITY\NETWORK SERVICE 2019-02-14 04:20:54.630     A logon
# 60            NT AUTHORITY\SYSTEM 2019-02-14 03:00:42.233     A logon
# 6             NT AUTHORITY\SYSTEM 2019-02-12 04:50:18.660     A logon
# 144           NT AUTHORITY\SYSTEM 2019-02-12 21:58:50.563     A logon
# 66            NT AUTHORITY\SYSTEM 2019-02-14 04:21:45.410     A logon
# 87            NT AUTHORITY\SYSTEM 2019-02-14 04:20:55.687     A logon
#
#      DayOfWeek
# 99     Tuesday
# 89    Thursday
# 32     Tuesday
# 3      Tuesday
# 123    Tuesday
# 47      Sunday
# 45      Sunday
# 1      Tuesday
# 81    Thursday
# 158     Friday
# 106  Wednesday
# 0      Tuesday
# 46      Sunday
# 27     Tuesday
# 72    Thursday
# 60    Thursday
# 6      Tuesday
# 144    Tuesday
# 66    Thursday
# 87    Thursday

# %% [markdown]
# ## Some other quick ways of filtering out (in) columns

# %%
logons_df.filter(regex="Target.*", axis=1).head()
# Out:
#     TargetUserName TargetDomainName  \
# 99           DWM-2   Window Manager
# 89          SYSTEM     NT AUTHORITY
# 32          SYSTEM     NT AUTHORITY
# 3       MSTICAdmin  MSTICAlertsWin1
# 123         SYSTEM     NT AUTHORITY
#
#                                     TargetUserSid TargetLogonId
# 99                                   S-1-5-90-0-2     0x106b458
# 89                                       S-1-5-18         0x3e7
# 32                                       S-1-5-18         0x3e7
# 3    S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 123                                      S-1-5-18         0x3e7

# %%
logons_df.select_dtypes(include="datetime").head()  # also "number", "object"
# Out:
#               TimeGenerated          TimeCreatedUtc
# 99  2019-02-12 22:22:21.240 2019-02-12 22:22:21.240
# 89  2019-02-14 04:20:55.763 2019-02-14 04:20:55.763
# 32  2019-02-12 06:42:08.110 2019-02-12 06:42:08.110
# 3   2019-02-12 04:38:16.550 2019-02-12 04:38:16.550
# 123 2019-02-12 20:39:14.110 2019-02-12 20:39:14.110

# %% [markdown]
# # Cleaning Data
#
# - Nans
# - Transforming
# - Reshaping

# %% [markdown]
# # Simple Joins
#
# (relational joins tomorrow)

# %%
df1 = logons_full_df[0:10]
df2 = logons_full_df[100:110]

print("df1:", df1.shape, "df2:", df2.shape)
df1.head(3)
# Out:
# df1: (10, 20) df2: (10, 20)
#                                TenantId                     Account  EventID  \
# 0  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM     4624
# 1  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
# 2  52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin     4624
#
#             TimeGenerated                      SourceComputerId  \
# 0 2019-02-12 04:56:34.307  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 1 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#           Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 0  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 1  MSTICAlertsWin1                 -                 -        S-1-0-0
# 2  MSTICAlertsWin1                 -                 -        S-1-0-0
#
#   TargetUserName TargetDomainName  \
# 0         SYSTEM     NT AUTHORITY
# 1     MSTICAdmin  MSTICAlertsWin1
# 2     MSTICAdmin  MSTICAlertsWin1
#
#                                   TargetUserSid TargetLogonId  \
# 0                                      S-1-5-18         0x3e7
# 1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
#
#   LogonProcessName  LogonType AuthenticationPackageName Status  \
# 0         Advapi            5                 Negotiate
# 1         NtLmSsp           3                      NTLM
# 2         NtLmSsp           3                      NTLM
#
#          IpAddress WorkstationName          TimeCreatedUtc
# 0                -               - 2019-02-12 04:56:34.307
# 1  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2  131.107.147.209  IANHELLE-DEV17 2019-02-12 04:37:27.997

# %%
joined_df = pd.concat([df1, df2])

print(joined_df.shape)
joined_df
# Out:
# (20, 20)
#                                  TenantId                     Account  \
# 0    52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 1    52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
# 2    52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
# 3    52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
# 4    52b1ab41-869e-4138-9e40-2a4457f09bf0  MSTICAlertsWin1\MSTICAdmin
# 5    52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 6    52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 7    52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 8    52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 9    52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 100  52b1ab41-869e-4138-9e40-2a4457f09bf0        Window Manager\DWM-2
# 101  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 102  52b1ab41-869e-4138-9e40-2a4457f09bf0         MSTICAlertsWin1\ian
# 103  52b1ab41-869e-4138-9e40-2a4457f09bf0         MSTICAlertsWin1\ian
# 104  52b1ab41-869e-4138-9e40-2a4457f09bf0         MSTICAlertsWin1\ian
# 105  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 106  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 107  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 108  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
# 109  52b1ab41-869e-4138-9e40-2a4457f09bf0         NT AUTHORITY\SYSTEM
#
#      EventID           TimeGenerated                      SourceComputerId  \
# 0       4624 2019-02-12 04:56:34.307  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 1       4624 2019-02-12 04:37:25.340  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 2       4624 2019-02-12 04:37:27.997  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 3       4624 2019-02-12 04:38:16.550  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 4       4624 2019-02-12 04:38:21.370  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 5       4624 2019-02-12 04:50:09.713  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 6       4624 2019-02-12 04:50:18.660  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 7       4624 2019-02-12 04:43:56.327  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 8       4624 2019-02-12 04:44:10.343  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 9       4624 2019-02-12 04:40:11.867  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 100     4624 2019-02-12 22:22:21.240  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 101     4624 2019-02-13 00:57:06.550  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 102     4624 2019-02-13 00:57:19.930  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 103     4624 2019-02-13 00:57:37.187  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 104     4624 2019-02-13 00:55:38.670  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 105     4624 2019-02-13 04:44:32.913  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 106     4624 2019-02-13 03:15:18.813  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 107     4624 2019-02-13 20:08:47.880  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 108     4624 2019-02-12 21:53:36.280  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 109     4624 2019-02-12 21:53:53.453  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#             Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 0    MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 1    MSTICAlertsWin1                 -                 -        S-1-0-0
# 2    MSTICAlertsWin1                 -                 -        S-1-0-0
# 3    MSTICAlertsWin1                 -                 -        S-1-0-0
# 4    MSTICAlertsWin1                 -                 -        S-1-0-0
# 5    MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 6    MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 7    MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 8    MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 9    MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 100  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 101  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 102  MSTICAlertsWin1                 -                 -        S-1-0-0
# 103  MSTICAlertsWin1                 -                 -        S-1-0-0
# 104  MSTICAlertsWin1                 -                 -        S-1-0-0
# 105  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 106  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 107  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 108  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 109  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#     TargetUserName TargetDomainName  \
# 0           SYSTEM     NT AUTHORITY
# 1       MSTICAdmin  MSTICAlertsWin1
# 2       MSTICAdmin  MSTICAlertsWin1
# 3       MSTICAdmin  MSTICAlertsWin1
# 4       MSTICAdmin  MSTICAlertsWin1
# 5           SYSTEM     NT AUTHORITY
# 6           SYSTEM     NT AUTHORITY
# 7           SYSTEM     NT AUTHORITY
# 8           SYSTEM     NT AUTHORITY
# 9           SYSTEM     NT AUTHORITY
# 100          DWM-2   Window Manager
# 101         SYSTEM     NT AUTHORITY
# 102            ian  MSTICAlertsWin1
# 103            ian  MSTICAlertsWin1
# 104            ian  MSTICAlertsWin1
# 105         SYSTEM     NT AUTHORITY
# 106         SYSTEM     NT AUTHORITY
# 107         SYSTEM     NT AUTHORITY
# 108         SYSTEM     NT AUTHORITY
# 109         SYSTEM     NT AUTHORITY
#
#                                      TargetUserSid TargetLogonId  \
# 0                                         S-1-5-18         0x3e7
# 1     S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2     S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
# 3     S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 4     S-1-5-21-996632719-2361334927-4038480536-500     0xc913737
# 5                                         S-1-5-18         0x3e7
# 6                                         S-1-5-18         0x3e7
# 7                                         S-1-5-18         0x3e7
# 8                                         S-1-5-18         0x3e7
# 9                                         S-1-5-18         0x3e7
# 100                                   S-1-5-90-0-2     0x106b46b
# 101                                       S-1-5-18         0x3e7
# 102  S-1-5-21-996632719-2361334927-4038480536-1120     0x15a1d83
# 103  S-1-5-21-996632719-2361334927-4038480536-1120     0x15a26d7
# 104  S-1-5-21-996632719-2361334927-4038480536-1120     0x158943d
# 105                                       S-1-5-18         0x3e7
# 106                                       S-1-5-18         0x3e7
# 107                                       S-1-5-18         0x3e7
# 108                                       S-1-5-18         0x3e7
# 109                                       S-1-5-18         0x3e7
#
#     LogonProcessName  LogonType AuthenticationPackageName Status  \
# 0           Advapi            5                 Negotiate
# 1           NtLmSsp           3                      NTLM
# 2           NtLmSsp           3                      NTLM
# 3           NtLmSsp           3                      NTLM
# 4           NtLmSsp           3                      NTLM
# 5           Advapi            5                 Negotiate
# 6           Advapi            5                 Negotiate
# 7           Advapi            5                 Negotiate
# 8           Advapi            5                 Negotiate
# 9           Advapi            5                 Negotiate
# 100         Advapi            2                 Negotiate
# 101         Advapi            5                 Negotiate
# 102         NtLmSsp           3                      NTLM
# 103         NtLmSsp           3                      NTLM
# 104         NtLmSsp           3                      NTLM
# 105         Advapi            5                 Negotiate
# 106         Advapi            5                 Negotiate
# 107         Advapi            5                 Negotiate
# 108         Advapi            5                 Negotiate
# 109         Advapi            5                 Negotiate
#
#            IpAddress   WorkstationName          TimeCreatedUtc
# 0                  -                 - 2019-02-12 04:56:34.307
# 1    131.107.147.209    IANHELLE-DEV17 2019-02-12 04:37:25.340
# 2    131.107.147.209    IANHELLE-DEV17 2019-02-12 04:37:27.997
# 3    131.107.147.209    IANHELLE-DEV17 2019-02-12 04:38:16.550
# 4    131.107.147.209    IANHELLE-DEV17 2019-02-12 04:38:21.370
# 5                  -                 - 2019-02-12 04:50:09.713
# 6                  -                 - 2019-02-12 04:50:18.660
# 7                  -                 - 2019-02-12 04:43:56.327
# 8                  -                 - 2019-02-12 04:44:10.343
# 9                  -                 - 2019-02-12 04:40:11.867
# 100                -                 - 2019-02-12 22:22:21.240
# 101                -                 - 2019-02-13 00:57:06.550
# 102         10.0.3.4  MSTICALERTSLXVM2 2019-02-13 00:57:19.930
# 103         10.0.3.4  MSTICALERTSLXVM2 2019-02-13 00:57:37.187
# 104         10.0.3.4  MSTICALERTSLXVM2 2019-02-13 00:55:38.670
# 105                -                 - 2019-02-13 04:44:32.913
# 106                -                 - 2019-02-13 03:15:18.813
# 107                -                 - 2019-02-13 20:08:47.880
# 108                -                 - 2019-02-12 21:53:36.280
# 109                -                 - 2019-02-12 21:53:53.453

# %%
df_list = [df1] * 3 + [df2] * 5
joined_df = pd.concat(df_list, ignore_index=True)

print(joined_df.shape)
joined_df.tail(5)
# Out:
# (80, 20)
#                                 TenantId              Account  EventID  \
# 75  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 76  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 77  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 78  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
# 79  52b1ab41-869e-4138-9e40-2a4457f09bf0  NT AUTHORITY\SYSTEM     4624
#
#              TimeGenerated                      SourceComputerId  \
# 75 2019-02-13 04:44:32.913  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 76 2019-02-13 03:15:18.813  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 77 2019-02-13 20:08:47.880  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 78 2019-02-12 21:53:36.280  263a788b-6526-4cdc-8ed9-d79402fe4aa0
# 79 2019-02-12 21:53:53.453  263a788b-6526-4cdc-8ed9-d79402fe4aa0
#
#            Computer   SubjectUserName SubjectDomainName SubjectUserSid  \
# 75  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 76  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 77  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 78  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 79  MSTICAlertsWin1  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
#
#    TargetUserName TargetDomainName TargetUserSid TargetLogonId  \
# 75         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 76         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 77         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 78         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
# 79         SYSTEM     NT AUTHORITY      S-1-5-18         0x3e7
#
#    LogonProcessName  LogonType AuthenticationPackageName Status IpAddress  \
# 75         Advapi            5                 Negotiate                -
# 76         Advapi            5                 Negotiate                -
# 77         Advapi            5                 Negotiate                -
# 78         Advapi            5                 Negotiate                -
# 79         Advapi            5                 Negotiate                -
#
#    WorkstationName          TimeCreatedUtc
# 75               - 2019-02-13 04:44:32.913
# 76               - 2019-02-13 03:15:18.813
# 77               - 2019-02-13 20:08:47.880
# 78               - 2019-02-12 21:53:36.280
# 79               - 2019-02-12 21:53:53.453

# %% [markdown]
# ## Joining columns (horizontal)

# %%
df_col_1 = logons_full_df[0:10].filter(regex="Subject.*")
df_col_2 = logons_full_df[0:10].filter(regex="Target.*")
print(df_col_1.shape, df_col_2.shape)
df_col_1.head()
# Out:
# (10, 3) (10, 4)
#     SubjectUserName SubjectDomainName SubjectUserSid
# 0  MSTICAlertsWin1$         WORKGROUP       S-1-5-18
# 1                 -                 -        S-1-0-0
# 2                 -                 -        S-1-0-0
# 3                 -                 -        S-1-0-0
# 4                 -                 -        S-1-0-0

# %%
pd.concat([df_col_1, df_col_2], axis="columns")
# Out:
#     SubjectUserName SubjectDomainName SubjectUserSid TargetUserName  \
# 0  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 1                 -                 -        S-1-0-0     MSTICAdmin
# 2                 -                 -        S-1-0-0     MSTICAdmin
# 3                 -                 -        S-1-0-0     MSTICAdmin
# 4                 -                 -        S-1-0-0     MSTICAdmin
# 5  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 6  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 7  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 8  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
# 9  MSTICAlertsWin1$         WORKGROUP       S-1-5-18         SYSTEM
#
#   TargetDomainName                                 TargetUserSid TargetLogonId
# 0     NT AUTHORITY                                      S-1-5-18         0x3e7
# 1  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90e957
# 2  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500     0xc90ea44
# 3  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500     0xc912d62
# 4  MSTICAlertsWin1  S-1-5-21-996632719-2361334927-4038480536-500     0xc913737
# 5     NT AUTHORITY                                      S-1-5-18         0x3e7
# 6     NT AUTHORITY                                      S-1-5-18         0x3e7
# 7     NT AUTHORITY                                      S-1-5-18         0x3e7
# 8     NT AUTHORITY                                      S-1-5-18         0x3e7
# 9     NT AUTHORITY                                      S-1-5-18         0x3e7
